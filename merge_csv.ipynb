# %%
import pandas as pd

# %%
avg_price_df = pd.read_csv("aggregated/avg_price.csv", encoding="utf-8")
hotel_detail_df = pd.read_csv("aggregated/hotels.csv", encoding="utf-8")

# %%
merged_hotel_df = pd.merge(avg_price_df, hotel_detail_df, how="inner", on="Hotel Name")
merged_hotel_df
# Out:
#                   Hotel Name  Advertised Price  Total Price      city  \
# 0    1 Hotel Brooklyn Bridge        640.576923   672.538462  New York
# 1       1 Hotel Central Park        586.541667   575.083333  New York
# 2    Aliz Hotel Times Square        329.686275   416.176471  New York
# 3              Americana Inn        165.486486   208.081081  New York
# 4                 Arlo NoMad        313.941176   392.215686  New York
# ..                       ...               ...          ...       ...
# 86               Union Hotel        168.179487   198.923077  New York
# 87      Walker Hotel Tribeca        406.750000   504.687500  New York
# 88   Washington Square Hotel        320.723404   371.893617  New York
# 89  Wyndham Garden Chinatown        283.300000   328.580000  New York
# 90  citizenM New York Bowery        328.019608   379.921569  New York
#
#                     address1  \
# 0    1 Hotel Brooklyn Bridge
# 1       1 Hotel Central Park
# 2    Aliz Hotel Times Square
# ...

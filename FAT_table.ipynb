# %%
import pandas as pd

# %%
june2_csv = "HotelData/June2_expedia.csv"
june9_csv = "HotelData/June9_expedia.csv"
june16_csv = "HotelData/June16_expedia.csv"
june23_csv = "HotelData/June23_expedia.csv"
june30_csv = "HotelData/June30_expedia.csv"

july7_csv = "HotelData/July7_expedia.csv"
july14_csv = "HotelData/July14_expedia.csv"
july21_csv = "HotelData/July21_expedia.csv"
july28_csv = "HotelData/July28_expedia.csv"

august4_csv = "HotelData/August4_expedia.csv"
august11_csv = "HotelData/August11_expedia.csv"
august18_csv = "HotelData/August18_expedia.csv"
august25_csv = "HotelData/August25_expedia.csv"

september1_csv = "HotelData/September1_expedia.csv"
september8_csv = "HotelData/September8_expedia.csv"
september15_csv = "HotelData/September15_expedia.csv"
september22_csv = "HotelData/September22_expedia.csv"
september29_csv = "HotelData/September29_expedia.csv"

october6_csv = "HotelData/October6_expedia.csv"
october13_csv = "HotelData/October13_expedia.csv"
october20_csv = "HotelData/October20_expedia.csv"
october27_csv = "HotelData/October27_expedia.csv"

november3_csv = "HotelData/November3_expedia.csv"
november10_csv = "HotelData/November10_expedia.csv"
november17_csv = "HotelData/November17_expedia.csv"
november24_csv = "HotelData/November24_expedia.csv"

december1_csv = "HotelData/December1_expedia.csv"
december8_csv = "HotelData/December8_expedia.csv"
december15_csv = "HotelData/December15_expedia.csv"
december22_csv = "HotelData/December22_expedia.csv"
december29_csv = "HotelData/December29_expedia.csv"

january5_csv = "HotelData/January5_expedia.csv"
january12_csv = "HotelData/January12_expedia.csv"
january19_csv = "HotelData/January19_expedia.csv"
january26_csv = "HotelData/January26_expedia.csv"

february2_csv = "HotelData/February2_expedia.csv"
february9_csv = "HotelData/February9_expedia.csv"
february16_csv = "HotelData/February16_expedia.csv"
february23_csv = "HotelData/February23_expedia.csv"

march1_csv = "HotelData/March1_expedia.csv"
march8_csv = "HotelData/March8_expedia.csv"
march15_csv = "HotelData/March15_expedia.csv"
march22_csv = "HotelData/March22_expedia.csv"
march29_csv = "HotelData/March29_expedia.csv"

april5_csv = "HotelData/April5_expedia.csv"
april12_csv = "HotelData/April12_expedia.csv"
april19_csv = "HotelData/April19_expedia.csv"
april26_csv = "HotelData/April26_expedia.csv"

may3_csv = "HotelData/May3_expedia.csv"
may10_csv = "HotelData/May10_expedia.csv"
may17_csv = "HotelData/May17_expedia.csv"
may24_csv = "HotelData/May24_expedia.csv"

# %%
june2_df = pd.read_csv(june2_csv)
june9_df = pd.read_csv(june9_csv)
june16_df = pd.read_csv(june16_csv)
june23_df = pd.read_csv(june23_csv)
june30_df = pd.read_csv(june30_csv)

july7_df = pd.read_csv(july7_csv)
july14_df = pd.read_csv(july14_csv)
july21_df = pd.read_csv(july21_csv)
july28_df = pd.read_csv(july28_csv)

august4_df = pd.read_csv(august4_csv)
august11_df = pd.read_csv(august11_csv)
august18_df = pd.read_csv(august18_csv)
august25_df = pd.read_csv(august25_csv)

september1_df = pd.read_csv(september1_csv)
september8_df = pd.read_csv(september8_csv)
september15_df = pd.read_csv(september15_csv)
september22_df = pd.read_csv(september22_csv)
september29_df = pd.read_csv(september29_csv)

october6_df = pd.read_csv(october6_csv)
october13_df = pd.read_csv(october13_csv)
october20_df = pd.read_csv(october20_csv)
october27_df = pd.read_csv(october27_csv)

november3_df = pd.read_csv(november3_csv)
november10_df = pd.read_csv(november10_csv)
november17_df = pd.read_csv(november17_csv)
november24_df = pd.read_csv(november24_csv)

december1_df = pd.read_csv(december1_csv)
december8_df = pd.read_csv(december8_csv)
december15_df = pd.read_csv(december15_csv)
december22_df = pd.read_csv(december22_csv)
december29_df = pd.read_csv(december29_csv)

january5_df = pd.read_csv(january5_csv)
january12_df = pd.read_csv(january12_csv)
january19_df = pd.read_csv(january19_csv)
january26_df = pd.read_csv(january26_csv)

february2_df = pd.read_csv(february2_csv)
february9_df = pd.read_csv(february9_csv)
february16_df = pd.read_csv(february16_csv)
february23_df = pd.read_csv(february23_csv)

march1_df = pd.read_csv(march1_csv)
march8_df = pd.read_csv(march8_csv)
march15_df = pd.read_csv(march15_csv)
march22_df = pd.read_csv(march22_csv)
march29_df = pd.read_csv(march29_csv)

april5_df = pd.read_csv(april5_csv)
april12_df = pd.read_csv(april12_csv)
april19_df = pd.read_csv(april19_csv)
april26_df = pd.read_csv(april26_csv)

may3_df = pd.read_csv(may3_csv)
may10_df = pd.read_csv(may10_csv)
may17_df = pd.read_csv(may17_csv)
may24_df = pd.read_csv(may24_csv)

# %%
june2_df
# Out:
#                                             Hotel Name  Advertised Price  \
# 0                             31 Street Broadway Hotel  The price is $69
# 1                                      Americana Motel  The price is $70
# 2                            Days Inn by Wyndham Wayne  The price is $91
# 3                   Quality Inn Wayne - Fairfield Area  The price is $95
# 4            Americas Best Value Inn Avenel Woodbridge  The price is $99
# ..                                                 ...               ...
# 795                                   HI New York City   We are sold out
# 796  FEMALES ONLY <br>Quite safe neighborhood near ...       Unavailable
# 797     Extended Stay America Suites Newark Woodbridge       Unavailable
# 798                                     Quiet getaway.       Unavailable
# 799                        Cozy Shack-1 Bedroom Studio   We are sold out
#
#          Total Price
# 0         $277 total
# 1          $80 total
# 2         $104 total
# ...

# %%
june2_df["Check-In Date"] = "6/2/2023"
june2_df["Check-Out Date"] = "6/4/2023"
june2_df
# Out:
#                                             Hotel Name  Advertised Price  \
# 0                             31 Street Broadway Hotel  The price is $69
# 1                                      Americana Motel  The price is $70
# 2                            Days Inn by Wyndham Wayne  The price is $91
# 3                   Quality Inn Wayne - Fairfield Area  The price is $95
# 4            Americas Best Value Inn Avenel Woodbridge  The price is $99
# ..                                                 ...               ...
# 795                                   HI New York City   We are sold out
# 796  FEMALES ONLY <br>Quite safe neighborhood near ...       Unavailable
# 797     Extended Stay America Suites Newark Woodbridge       Unavailable
# 798                                     Quiet getaway.       Unavailable
# 799                        Cozy Shack-1 Bedroom Studio   We are sold out
#
#          Total Price Check-In Date Check-Out Date
# ...

# %%
cols = ["Check-In Date", "Check-Out Date", "Hotel Name", "Advertised Price", "Total Price"]

# %%
june2_df = june2_df[cols]

# %%
june2_df
# Out:
#     Check-In Date Check-Out Date  \
# 0        6/2/2023       6/4/2023
# 1        6/2/2023       6/4/2023
# 2        6/2/2023       6/4/2023
# 3        6/2/2023       6/4/2023
# 4        6/2/2023       6/4/2023
# ..            ...            ...
# 795      6/2/2023       6/4/2023
# 796      6/2/2023       6/4/2023
# 797      6/2/2023       6/4/2023
# 798      6/2/2023       6/4/2023
# 799      6/2/2023       6/4/2023
#
#                                             Hotel Name  Advertised Price  \
# 0                             31 Street Broadway Hotel  The price is $69
# 1                                      Americana Motel  The price is $70
# 2                            Days Inn by Wyndham Wayne  The price is $91
# 3                   Quality Inn Wayne - Fairfield Area  The price is $95
# 4            Americas Best Value Inn Avenel Woodbridge  The price is $99
# ..                                                 ...               ...
# ...

# %%
june9_df["Check-In Date"] = "6/9/2023"
june9_df["Check-Out Date"] = "6/11/2023"
june9_df = june9_df[cols]
june9_df
# Out:
#     Check-In Date Check-Out Date  \
# 0        6/9/2023      6/11/2023
# 1        6/9/2023      6/11/2023
# 2        6/9/2023      6/11/2023
# 3        6/9/2023      6/11/2023
# 4        6/9/2023      6/11/2023
# ..            ...            ...
# 795      6/9/2023      6/11/2023
# 796      6/9/2023      6/11/2023
# 797      6/9/2023      6/11/2023
# 798      6/9/2023      6/11/2023
# 799      6/9/2023      6/11/2023
#
#                                             Hotel Name  Advertised Price  \
# 0                                      Americana Motel  The price is $70
# 1    Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 2                                       Cozy and Quiet  The price is $88
# 3                             31 Street Broadway Hotel  The price is $89
# 4                            Days Inn by Wyndham Wayne  The price is $91
# ..                                                 ...               ...
# ...

# %%
june16_df["Check-In Date"] = "6/16/2023"
june16_df["Check-Out Date"] = "6/18/2023"
june16_df = june16_df[cols]
june16_df
# Out:
#     Check-In Date Check-Out Date  \
# 0       6/16/2023      6/18/2023
# 1       6/16/2023      6/18/2023
# 2       6/16/2023      6/18/2023
# 3       6/16/2023      6/18/2023
# 4       6/16/2023      6/18/2023
# ..            ...            ...
# 795     6/16/2023      6/18/2023
# 796     6/16/2023      6/18/2023
# 797     6/16/2023      6/18/2023
# 798     6/16/2023      6/18/2023
# 799     6/16/2023      6/18/2023
#
#                                             Hotel Name  Advertised Price  \
# 0                                      Americana Motel  The price is $70
# 1                                       Cozy and Quiet  The price is $80
# 2    Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 3                             31 Street Broadway Hotel  The price is $89
# 4                            Days Inn by Wyndham Wayne  The price is $91
# ..                                                 ...               ...
# ...

# %%
june23_df["Check-In Date"] = "6/23/2023"
june23_df["Check-Out Date"] = "6/25/2023"
june23_df = june23_df[cols]
june23_df
# Out:
#     Check-In Date Check-Out Date  \
# 0       6/23/2023      6/25/2023
# 1       6/23/2023      6/25/2023
# 2       6/23/2023      6/25/2023
# 3       6/23/2023      6/25/2023
# 4       6/23/2023      6/25/2023
# ..            ...            ...
# 795     6/23/2023      6/25/2023
# 796     6/23/2023      6/25/2023
# 797     6/23/2023      6/25/2023
# 798     6/23/2023      6/25/2023
# 799     6/23/2023      6/25/2023
#
#                                             Hotel Name   Advertised Price  \
# 0                                       Cozy and Quiet   The price is $98
# 1                            Days Inn by Wyndham Wayne   The price is $99
# 2            Americas Best Value Inn Avenel Woodbridge   The price is $99
# 3                            Luxe Autos Exotic Rentals   The price is $99
# 4                                          Rodeway Inn  The price is $101
# ..                                                 ...                ...
# ...

# %%
june30_df["Check-In Date"] = "6/30/2023"
june30_df["Check-Out Date"] = "7/2/2023"
june30_df = june30_df[cols]
june30_df
# Out:
#     Check-In Date Check-Out Date  \
# 0       6/30/2023       7/2/2023
# 1       6/30/2023       7/2/2023
# 2       6/30/2023       7/2/2023
# 3       6/30/2023       7/2/2023
# 4       6/30/2023       7/2/2023
# ..            ...            ...
# 794     6/30/2023       7/2/2023
# 795     6/30/2023       7/2/2023
# 796     6/30/2023       7/2/2023
# 797     6/30/2023       7/2/2023
# 798     6/30/2023       7/2/2023
#
#                                             Hotel Name  Advertised Price  \
# 0                                      Americana Motel  The price is $70
# 1    Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 2                                       Cozy and Quiet  The price is $90
# 3                            Days Inn by Wyndham Wayne  The price is $91
# 4            Americas Best Value Inn Avenel Woodbridge  The price is $99
# ..                                                 ...               ...
# ...

# %%
june2023_df = pd.concat([june2_df, june9_df, june16_df, june23_df, june30_df], axis=0)
june2023_df
# Out:
#     Check-In Date Check-Out Date  \
# 0        6/2/2023       6/4/2023
# 1        6/2/2023       6/4/2023
# 2        6/2/2023       6/4/2023
# 3        6/2/2023       6/4/2023
# 4        6/2/2023       6/4/2023
# ..            ...            ...
# 794     6/30/2023       7/2/2023
# 795     6/30/2023       7/2/2023
# 796     6/30/2023       7/2/2023
# 797     6/30/2023       7/2/2023
# 798     6/30/2023       7/2/2023
#
#                                             Hotel Name  Advertised Price  \
# 0                             31 Street Broadway Hotel  The price is $69
# 1                                      Americana Motel  The price is $70
# 2                            Days Inn by Wyndham Wayne  The price is $91
# 3                   Quality Inn Wayne - Fairfield Area  The price is $95
# 4            Americas Best Value Inn Avenel Woodbridge  The price is $99
# ..                                                 ...               ...
# ...

# %%
july7_df["Check-In Date"] = "7/7/2023"
july7_df["Check-Out Date"] = "7/9/2023"
july7_df = july7_df[cols]
july7_df
# Out:
#     Check-In Date Check-Out Date  \
# 0        7/7/2023       7/9/2023
# 1        7/7/2023       7/9/2023
# 2        7/7/2023       7/9/2023
# 3        7/7/2023       7/9/2023
# 4        7/7/2023       7/9/2023
# ..            ...            ...
# 795      7/7/2023       7/9/2023
# 796      7/7/2023       7/9/2023
# 797      7/7/2023       7/9/2023
# 798      7/7/2023       7/9/2023
# 799      7/7/2023       7/9/2023
#
#                                             Hotel Name   Advertised Price  \
# 0    Cozy 1st Floor / Basement Apartment 15 min fro...   The price is $85
# 1                            Days Inn by Wyndham Wayne   The price is $91
# 2                       Best Western The Inn At Ramsey  The price is $101
# 3                                          Rodeway Inn  The price is $101
# 4                   Quality Inn Spring Valley - Nanuet  The price is $107
# ..                                                 ...                ...
# ...

# %%
july14_df["Check-In Date"] = "7/14/2023"
july14_df["Check-Out Date"] = "7/16/2023"
july14_df = july14_df[cols]
july14_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     7/14/2023      7/16/2023
# 1     7/14/2023      7/16/2023
# 2     7/14/2023      7/16/2023
# 3     7/14/2023      7/16/2023
# 4     7/14/2023      7/16/2023
#
#                                           Hotel Name   Advertised Price  \
# 0  Cozy 1st Floor / Basement Apartment 15 min fro...   The price is $85
# 1                          Days Inn by Wyndham Wayne   The price is $91
# 2          Americas Best Value Inn Avenel Woodbridge   The price is $99
# 3                     Best Western The Inn At Ramsey  The price is $101
# 4                                        Rodeway Inn  The price is $101
#
#   Total Price
# 0  $171 total
# 1  $104 total
# 2  $113 total
# 3  $116 total
# 4  $113 total

# %%
july21_df["Check-In Date"] = "7/21/2023"
july21_df["Check-Out Date"] = "7/23/2023"
july21_df = july21_df[cols]
july21_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     7/21/2023      7/23/2023
# 1     7/21/2023      7/23/2023
# 2     7/21/2023      7/23/2023
# 3     7/21/2023      7/23/2023
# 4     7/21/2023      7/23/2023
#
#                                           Hotel Name   Advertised Price  \
# 0  Cozy 1st Floor / Basement Apartment 15 min fro...   The price is $85
# 1          Americas Best Value Inn Avenel Woodbridge   The price is $99
# 2                     Best Western The Inn At Ramsey  The price is $101
# 3                                        Rodeway Inn  The price is $101
# 4                Red Carpet Inn Newark Irvington, NJ  The price is $103
#
#   Total Price
# 0  $171 total
# 1  $113 total
# 2  $116 total
# 3  $113 total
# 4  $119 total

# %%
july28_df["Check-In Date"] = "7/28/2023"
july28_df["Check-Out Date"] = "7/30/2023"
july28_df = july28_df[cols]
july28_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     7/28/2023      7/30/2023
# 1     7/28/2023      7/30/2023
# 2     7/28/2023      7/30/2023
# 3     7/28/2023      7/30/2023
# 4     7/28/2023      7/30/2023
#
#                                           Hotel Name   Advertised Price  \
# 0  Cozy 1st Floor / Basement Apartment 15 min fro...   The price is $85
# 1                          Days Inn by Wyndham Wayne   The price is $88
# 2          Americas Best Value Inn Avenel Woodbridge   The price is $99
# 3                                 Bowery Grand Hotel  The price is $100
# 4                     Best Western The Inn At Ramsey  The price is $101
#
#   Total Price
# 0  $171 total
# 1  $101 total
# 2  $113 total
# 3  $118 total
# 4  $116 total

# %%
july2023_df = pd.concat([july7_df, july14_df, july21_df, july28_df], axis=0)
july2023_df
# Out:
#     Check-In Date Check-Out Date  \
# 0        7/7/2023       7/9/2023
# 1        7/7/2023       7/9/2023
# 2        7/7/2023       7/9/2023
# 3        7/7/2023       7/9/2023
# 4        7/7/2023       7/9/2023
# ..            ...            ...
# 795     7/28/2023      7/30/2023
# 796     7/28/2023      7/30/2023
# 797     7/28/2023      7/30/2023
# 798     7/28/2023      7/30/2023
# 799     7/28/2023      7/30/2023
#
#                                             Hotel Name   Advertised Price  \
# 0    Cozy 1st Floor / Basement Apartment 15 min fro...   The price is $85
# 1                            Days Inn by Wyndham Wayne   The price is $91
# 2                       Best Western The Inn At Ramsey  The price is $101
# 3                                          Rodeway Inn  The price is $101
# 4                   Quality Inn Spring Valley - Nanuet  The price is $107
# ..                                                 ...                ...
# ...

# %%
august4_df["Check-In Date"] = "8/4/2023"
august4_df["Check-Out Date"] = "8/6/2023"
august4_df = august4_df[cols]
august4_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0      8/4/2023       8/6/2023
# 1      8/4/2023       8/6/2023
# 2      8/4/2023       8/6/2023
# 3      8/4/2023       8/6/2023
# 4      8/4/2023       8/6/2023
#
#                                           Hotel Name  Advertised Price  \
# 0                                    Americana Motel  The price is $70
# 1  Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 2                               Rest Inn - Elizabeth  The price is $92
# 3          Americas Best Value Inn Avenel Woodbridge  The price is $99
# 4                                         Swan Motel  The price is $99
#
#   Total Price
# 0   $80 total
# 1  $171 total
# 2  $106 total
# 3  $113 total
# 4  $113 total

# %%
august11_df["Check-In Date"] = "8/11/2023"
august11_df["Check-Out Date"] = "8/13/2023"
august11_df = august11_df[cols]
august11_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     8/11/2023      8/13/2023
# 1     8/11/2023      8/13/2023
# 2     8/11/2023      8/13/2023
# 3     8/11/2023      8/13/2023
# 4     8/11/2023      8/13/2023
#
#                                           Hotel Name  Advertised Price  \
# 0                                    Americana Motel  The price is $70
# 1  Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 2                          Days Inn by Wyndham Wayne  The price is $91
# 3   Newly Constructed Basement Two Bedroom Apartment  The price is $95
# 4      DreamBox Vrbo! Where Dreams Become A Reality!  The price is $95
#
#   Total Price
# 0   $80 total
# 1  $171 total
# 2  $104 total
# 3  $171 total
# 4  $257 total

# %%
august18_df["Check-In Date"] = "8/18/2023"
august18_df["Check-Out Date"] = "8/20/2023"
august18_df = august18_df[cols]
august18_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     8/18/2023      8/20/2023
# 1     8/18/2023      8/20/2023
# 2     8/18/2023      8/20/2023
# 3     8/18/2023      8/20/2023
# 4     8/18/2023      8/20/2023
#
#                                           Hotel Name   Advertised Price  \
# 0  Cozy 1st Floor / Basement Apartment 15 min fro...   The price is $85
# 1                          Days Inn by Wyndham Wayne   The price is $91
# 2                                         Swan Motel   The price is $99
# 3          Americas Best Value Inn Avenel Woodbridge   The price is $99
# 4     La Quinta Inn & Suites by Wyndham Fairfield NJ  The price is $101
#
#   Total Price
# 0  $171 total
# 1  $104 total
# 2  $113 total
# 3  $113 total
# 4  $116 total

# %%
august25_df["Check-In Date"] = "8/25/2023"
august25_df["Check-Out Date"] = "8/27/2023"
august25_df = august25_df[cols]
august25_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     8/25/2023      8/27/2023
# 1     8/25/2023      8/27/2023
# 2     8/25/2023      8/27/2023
# 3     8/25/2023      8/27/2023
# 4     8/25/2023      8/27/2023
#
#                                           Hotel Name   Advertised Price  \
# 0  Cozy 1st Floor / Basement Apartment 15 min fro...   The price is $85
# 1                          Days Inn by Wyndham Wayne   The price is $91
# 2                                         Swan Motel   The price is $99
# 3          Americas Best Value Inn Avenel Woodbridge   The price is $99
# 4     La Quinta Inn & Suites by Wyndham Fairfield NJ  The price is $101
#
#   Total Price
# 0  $171 total
# 1  $104 total
# 2  $113 total
# 3  $113 total
# 4  $116 total

# %%
august2023_df = pd.concat([august4_df, august11_df, august18_df, august25_df], axis=0)
august2023_df
# Out:
#     Check-In Date Check-Out Date  \
# 0        8/4/2023       8/6/2023
# 1        8/4/2023       8/6/2023
# 2        8/4/2023       8/6/2023
# 3        8/4/2023       8/6/2023
# 4        8/4/2023       8/6/2023
# ..            ...            ...
# 795     8/25/2023      8/27/2023
# 796     8/25/2023      8/27/2023
# 797     8/25/2023      8/27/2023
# 798     8/25/2023      8/27/2023
# 799     8/25/2023      8/27/2023
#
#                                             Hotel Name  Advertised Price  \
# 0                                      Americana Motel  The price is $70
# 1    Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 2                                 Rest Inn - Elizabeth  The price is $92
# 3            Americas Best Value Inn Avenel Woodbridge  The price is $99
# 4                                           Swan Motel  The price is $99
# ..                                                 ...               ...
# ...

# %%
september1_df["Check-In Date"] = "9/1/2023"
september1_df["Check-Out Date"] = "9/3/2023"
september1_df = september1_df[cols]
september1_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0      9/1/2023       9/3/2023
# 1      9/1/2023       9/3/2023
# 2      9/1/2023       9/3/2023
# 3      9/1/2023       9/3/2023
# 4      9/1/2023       9/3/2023
#
#                                           Hotel Name  Advertised Price  \
# 0  Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 1  Cozzy Get Away Priv. Apt/ St BarnabaS Hosp/NYC...  The price is $92
# 2                                   Mamaroneck Motel  The price is $96
# 3                          Days Inn by Wyndham Wayne  The price is $99
# 4          Americas Best Value Inn Avenel Woodbridge  The price is $99
#
#   Total Price
# 0  $171 total
# 1  $123 total
# 2  $110 total
# 3  $113 total
# 4  $113 total

# %%
september8_df["Check-In Date"] = "9/8/2023"
september8_df["Check-Out Date"] = "9/10/2023"
september8_df = september8_df[cols]
september8_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0      9/8/2023      9/10/2023
# 1      9/8/2023      9/10/2023
# 2      9/8/2023      9/10/2023
# 3      9/8/2023      9/10/2023
# 4      9/8/2023      9/10/2023
#
#                                           Hotel Name  Advertised Price  \
# 0                          Days Inn by Wyndham Wayne  The price is $80
# 1  Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 2                 Quality Inn Wayne - Fairfield Area  The price is $93
# 3            Days Inn by Wyndham Iselin / Woodbridge  The price is $95
# 4                                   Mamaroneck Motel  The price is $96
#
#   Total Price
# 0   $92 total
# 1  $171 total
# 2  $107 total
# 3  $109 total
# 4  $110 total

# %%
september15_df["Check-In Date"] = "9/15/2023"
september15_df["Check-Out Date"] = "9/17/2023"
september15_df = september15_df[cols]
september15_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     9/15/2023      9/17/2023
# 1     9/15/2023      9/17/2023
# 2     9/15/2023      9/17/2023
# 3     9/15/2023      9/17/2023
# 4     9/15/2023      9/17/2023
#
#                                           Hotel Name  Advertised Price  \
# 0                          Days Inn by Wyndham Wayne  The price is $80
# 1            Days Inn by Wyndham Iselin / Woodbridge  The price is $81
# 2  Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 3                 Quality Inn Wayne - Fairfield Area  The price is $96
# 4                                   Mamaroneck Motel  The price is $96
#
#   Total Price
# 0   $92 total
# 1   $93 total
# 2  $171 total
# 3  $110 total
# 4  $110 total

# %%
september22_df["Check-In Date"] = "9/22/2023"
september22_df["Check-Out Date"] = "9/24/2023"
september22_df = september22_df[cols]
september22_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     9/22/2023      9/24/2023
# 1     9/22/2023      9/24/2023
# 2     9/22/2023      9/24/2023
# 3     9/22/2023      9/24/2023
# 4     9/22/2023      9/24/2023
#
#                                           Hotel Name  Advertised Price  \
# 0                          Days Inn by Wyndham Wayne  The price is $80
# 1  Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 2                                   Mamaroneck Motel  The price is $96
# 3                 Quality Inn Wayne - Fairfield Area  The price is $96
# 4          Americas Best Value Inn Avenel Woodbridge  The price is $99
#
#   Total Price
# 0   $92 total
# 1  $171 total
# 2  $110 total
# 3  $110 total
# 4  $113 total

# %%
september29_df["Check-In Date"] = "9/29/2023"
september29_df["Check-Out Date"] = "10/1/2023"
september29_df = september29_df[cols]
september29_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     9/29/2023      10/1/2023
# 1     9/29/2023      10/1/2023
# 2     9/29/2023      10/1/2023
# 3     9/29/2023      10/1/2023
# 4     9/29/2023      10/1/2023
#
#                                           Hotel Name  Advertised Price  \
# 0                          Days Inn by Wyndham Wayne  The price is $80
# 1            Days Inn by Wyndham Iselin / Woodbridge  The price is $81
# 2  Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 3                 Quality Inn Wayne - Fairfield Area  The price is $94
# 4                                   Mamaroneck Motel  The price is $96
#
#   Total Price
# 0   $92 total
# 1   $93 total
# 2  $171 total
# 3  $107 total
# 4  $110 total

# %%
september2023_df = pd.concat([september1_df, september8_df, september15_df, september22_df, september29_df], axis=0)
september2023_df
# Out:
#     Check-In Date Check-Out Date  \
# 0        9/1/2023       9/3/2023
# 1        9/1/2023       9/3/2023
# 2        9/1/2023       9/3/2023
# 3        9/1/2023       9/3/2023
# 4        9/1/2023       9/3/2023
# ..            ...            ...
# 795     9/29/2023      10/1/2023
# 796     9/29/2023      10/1/2023
# 797     9/29/2023      10/1/2023
# 798     9/29/2023      10/1/2023
# 799     9/29/2023      10/1/2023
#
#                                             Hotel Name  Advertised Price  \
# 0    Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 1    Cozzy Get Away Priv. Apt/ St BarnabaS Hosp/NYC...  The price is $92
# 2                                     Mamaroneck Motel  The price is $96
# 3                            Days Inn by Wyndham Wayne  The price is $99
# 4            Americas Best Value Inn Avenel Woodbridge  The price is $99
# ..                                                 ...               ...
# ...

# %%
october6_df["Check-In Date"] = "10/6/2023"
october6_df["Check-Out Date"] = "10/8/2023"
october6_df = october6_df[cols]
october6_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     10/6/2023      10/8/2023
# 1     10/6/2023      10/8/2023
# 2     10/6/2023      10/8/2023
# 3     10/6/2023      10/8/2023
# 4     10/6/2023      10/8/2023
#
#                                           Hotel Name  Advertised Price  \
# 0                                    Americana Motel  The price is $70
# 1    Luxury Private Room in Westfield, 1 hour to NYC  The price is $79
# 2            Days Inn by Wyndham Iselin / Woodbridge  The price is $85
# 3  Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 4                               Cozy Nights 2Bedroom  The price is $90
#
#   Total Price
# 0   $80 total
# 1  $164 total
# 2   $97 total
# 3  $171 total
# 4  $176 total

# %%
october13_df["Check-In Date"] = "10/13/2023"
october13_df["Check-Out Date"] = "10/15/2023"
october13_df = october13_df[cols]
october13_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0    10/13/2023     10/15/2023
# 1    10/13/2023     10/15/2023
# 2    10/13/2023     10/15/2023
# 3    10/13/2023     10/15/2023
# 4    10/13/2023     10/15/2023
#
#                                           Hotel Name  Advertised Price  \
# 0            Days Inn by Wyndham Iselin / Woodbridge  The price is $70
# 1  Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 2                          Days Inn by Wyndham Wayne  The price is $86
# 3                 Quality Inn Wayne - Fairfield Area  The price is $92
# 4                                      Phoenix Hotel  The price is $94
#
#   Total Price
# 0   $80 total
# 1  $171 total
# 2   $98 total
# 3  $106 total
# 4  $111 total

# %%
october20_df["Check-In Date"] = "10/20/2023"
october20_df["Check-Out Date"] = "10/22/2023"
october20_df = october20_df[cols]
october20_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0    10/20/2023     10/22/2023
# 1    10/20/2023     10/22/2023
# 2    10/20/2023     10/22/2023
# 3    10/20/2023     10/22/2023
# 4    10/20/2023     10/22/2023
#
#                                           Hotel Name  Advertised Price  \
# 0  WE LOVE NYC: Romantic and super clean private ...  The price is $58
# 1                                    Americana Motel  The price is $70
# 2            Days Inn by Wyndham Iselin / Woodbridge  The price is $71
# 3                          Days Inn by Wyndham Wayne  The price is $76
# 4  Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
#
#   Total Price
# 0  $104 total
# 1   $80 total
# 2   $81 total
# 3   $87 total
# 4  $171 total

# %%
october27_df["Check-In Date"] = "10/27/2023"
october27_df["Check-Out Date"] = "10/29/2023"
october27_df = october27_df[cols]
october27_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0    10/27/2023     10/29/2023
# 1    10/27/2023     10/29/2023
# 2    10/27/2023     10/29/2023
# 3    10/27/2023     10/29/2023
# 4    10/27/2023     10/29/2023
#
#                                           Hotel Name  Advertised Price  \
# 0                                    Americana Motel  The price is $70
# 1                          Days Inn by Wyndham Wayne  The price is $76
# 2            Days Inn by Wyndham Iselin / Woodbridge  The price is $83
# 3                           31 Street Broadway Hotel  The price is $85
# 4  Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
#
#   Total Price
# 0   $80 total
# 1   $87 total
# 2   $95 total
# 3  $307 total
# 4  $171 total

# %%
october2023_df = pd.concat([october6_df, october13_df, october20_df, october27_df], axis=0)
october2023_df
# Out:
#     Check-In Date Check-Out Date  \
# 0       10/6/2023      10/8/2023
# 1       10/6/2023      10/8/2023
# 2       10/6/2023      10/8/2023
# 3       10/6/2023      10/8/2023
# 4       10/6/2023      10/8/2023
# ..            ...            ...
# 794    10/27/2023     10/29/2023
# 795    10/27/2023     10/29/2023
# 796    10/27/2023     10/29/2023
# 797    10/27/2023     10/29/2023
# 798    10/27/2023     10/29/2023
#
#                                             Hotel Name  Advertised Price  \
# 0                                      Americana Motel  The price is $70
# 1      Luxury Private Room in Westfield, 1 hour to NYC  The price is $79
# 2              Days Inn by Wyndham Iselin / Woodbridge  The price is $85
# 3    Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 4                                 Cozy Nights 2Bedroom  The price is $90
# ..                                                 ...               ...
# ...

# %%
november3_df["Check-In Date"] = "11/3/2023"
november3_df["Check-Out Date"] = "11/5/2023"
november3_df = november3_df[cols]
november3_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     11/3/2023      11/5/2023
# 1     11/3/2023      11/5/2023
# 2     11/3/2023      11/5/2023
# 3     11/3/2023      11/5/2023
# 4     11/3/2023      11/5/2023
#
#                                           Hotel Name  Advertised Price  \
# 0                          Days Inn by Wyndham Wayne  The price is $76
# 1                    Tides Motor Inn at Stehli Beach  The price is $79
# 2            Days Inn by Wyndham Iselin / Woodbridge  The price is $85
# 3  Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 4                 Quality Inn Wayne - Fairfield Area  The price is $94
#
#   Total Price
# 0   $87 total
# 1   $88 total
# 2   $97 total
# 3  $171 total
# 4  $107 total

# %%
november10_df["Check-In Date"] = "11/10/2023"
november10_df["Check-Out Date"] = "11/12/2023"
november10_df = november10_df[cols]
november10_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0    11/10/2023     11/12/2023
# 1    11/10/2023     11/12/2023
# 2    11/10/2023     11/12/2023
# 3    11/10/2023     11/12/2023
# 4    11/10/2023     11/12/2023
#
#                                           Hotel Name  Advertised Price  \
# 0                          Days Inn by Wyndham Wayne  The price is $65
# 1                    Tides Motor Inn at Stehli Beach  The price is $79
# 2            Days Inn by Wyndham Iselin / Woodbridge  The price is $85
# 3  Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 4                 Quality Inn Wayne - Fairfield Area  The price is $93
#
#   Total Price
# 0   $75 total
# 1   $88 total
# 2   $97 total
# 3  $171 total
# 4  $106 total

# %%
november17_df["Check-In Date"] = "11/17/2023"
november17_df["Check-Out Date"] = "11/19/2023"
november17_df = november17_df[cols]
november17_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0    11/17/2023     11/19/2023
# 1    11/17/2023     11/19/2023
# 2    11/17/2023     11/19/2023
# 3    11/17/2023     11/19/2023
# 4    11/17/2023     11/19/2023
#
#                                           Hotel Name  Advertised Price  \
# 0                          Days Inn by Wyndham Wayne  The price is $76
# 1                    Tides Motor Inn at Stehli Beach  The price is $79
# 2            Days Inn by Wyndham Iselin / Woodbridge  The price is $85
# 3  Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 4                                      Phoenix Hotel  The price is $94
#
#   Total Price
# 0   $87 total
# 1   $88 total
# 2   $97 total
# 3  $171 total
# 4  $111 total

# %%
november24_df["Check-In Date"] = "11/24/2023"
november24_df["Check-Out Date"] = "11/26/2023"
november24_df = november24_df[cols]
november24_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0    11/24/2023     11/26/2023
# 1    11/24/2023     11/26/2023
# 2    11/24/2023     11/26/2023
# 3    11/24/2023     11/26/2023
# 4    11/24/2023     11/26/2023
#
#                                        Hotel Name  Advertised Price  \
# 0                       Days Inn by Wyndham Wayne  The price is $65
# 1                 Tides Motor Inn at Stehli Beach  The price is $79
# 2         Days Inn by Wyndham Iselin / Woodbridge  The price is $89
# 3  Extended Stay America Suites Newark Woodbridge  The price is $95
# 4      Days Inn by Wyndham Nanuet / Spring Valley  The price is $98
#
#   Total Price
# 0   $75 total
# 1   $88 total
# 2  $102 total
# 3  $109 total
# 4  $109 total

# %%
november2023_df = pd.concat([november3_df, november10_df, november17_df, november24_df], axis=0)
november2023_df
# Out:
#     Check-In Date Check-Out Date  \
# 0       11/3/2023      11/5/2023
# 1       11/3/2023      11/5/2023
# 2       11/3/2023      11/5/2023
# 3       11/3/2023      11/5/2023
# 4       11/3/2023      11/5/2023
# ..            ...            ...
# 737    11/24/2023     11/26/2023
# 738    11/24/2023     11/26/2023
# 739    11/24/2023     11/26/2023
# 740    11/24/2023     11/26/2023
# 741    11/24/2023     11/26/2023
#
#                                             Hotel Name  Advertised Price  \
# 0                            Days Inn by Wyndham Wayne  The price is $76
# 1                      Tides Motor Inn at Stehli Beach  The price is $79
# 2              Days Inn by Wyndham Iselin / Woodbridge  The price is $85
# 3    Cozy 1st Floor / Basement Apartment 15 min fro...  The price is $85
# 4                   Quality Inn Wayne - Fairfield Area  The price is $94
# ..                                                 ...               ...
# ...

# %%
december1_df["Check-In Date"] = "12/1/2023"
december1_df["Check-Out Date"] = "12/3/2023"
december1_df = december1_df[cols]
december1_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     12/1/2023      12/3/2023
# 1     12/1/2023      12/3/2023
# 2     12/1/2023      12/3/2023
# 3     12/1/2023      12/3/2023
# 4     12/1/2023      12/3/2023
#
#                                        Hotel Name  Advertised Price  \
# 0                       Days Inn by Wyndham Wayne  The price is $63
# 1                 Tides Motor Inn at Stehli Beach  The price is $79
# 2         Days Inn by Wyndham Iselin / Woodbridge  The price is $89
# 3  Extended Stay America Suites Newark Woodbridge  The price is $95
# 4      Days Inn by Wyndham Nanuet / Spring Valley  The price is $96
#
#   Total Price
# 0   $73 total
# 1   $88 total
# 2  $102 total
# 3  $109 total
# 4  $107 total

# %%
december8_df["Check-In Date"] = "12/8/2023"
december8_df["Check-Out Date"] = "12/10/2023"
december8_df = december8_df[cols]
december8_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     12/8/2023     12/10/2023
# 1     12/8/2023     12/10/2023
# 2     12/8/2023     12/10/2023
# 3     12/8/2023     12/10/2023
# 4     12/8/2023     12/10/2023
#
#                                           Hotel Name  Advertised Price  \
# 0  WE LOVE NYC: Romantic and super clean private ...  The price is $58
# 1                          Days Inn by Wyndham Wayne  The price is $63
# 2                                    Americana Motel  The price is $70
# 3                    Tides Motor Inn at Stehli Beach  The price is $79
# 4    Luxury Private Room in Westfield, 1 hour to NYC  The price is $79
#
#   Total Price
# 0  $104 total
# 1   $73 total
# 2   $80 total
# 3   $88 total
# 4  $164 total

# %%
december15_df["Check-In Date"] = "12/15/2023"
december15_df["Check-Out Date"] = "12/17/2023"
december15_df = december15_df[cols]
december15_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0    12/15/2023     12/17/2023
# 1    12/15/2023     12/17/2023
# 2    12/15/2023     12/17/2023
# 3    12/15/2023     12/17/2023
# 4    12/15/2023     12/17/2023
#
#                                           Hotel Name  Advertised Price  \
# 0  WE LOVE NYC: Romantic and super clean private ...  The price is $58
# 1                          Days Inn by Wyndham Wayne  The price is $63
# 2                                    Americana Motel  The price is $70
# 3                    Tides Motor Inn at Stehli Beach  The price is $79
# 4    Luxury Private Room in Westfield, 1 hour to NYC  The price is $79
#
#   Total Price
# 0  $104 total
# 1   $73 total
# 2   $80 total
# 3   $88 total
# 4  $164 total

# %%
december22_df["Check-In Date"] = "12/22/2023"
december22_df["Check-Out Date"] = "12/24/2023"
december22_df = december22_df[cols]
december22_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0    12/22/2023     12/24/2023
# 1    12/22/2023     12/24/2023
# 2    12/22/2023     12/24/2023
# 3    12/22/2023     12/24/2023
# 4    12/22/2023     12/24/2023
#
#                                         Hotel Name  Advertised Price  \
# 0                        Days Inn by Wyndham Wayne  The price is $63
# 1                                  Americana Motel  The price is $70
# 2                  Tides Motor Inn at Stehli Beach  The price is $79
# 3  Luxury Private Room in Westfield, 1 hour to NYC  The price is $79
# 4          Days Inn by Wyndham Iselin / Woodbridge  The price is $89
#
#   Total Price
# 0   $73 total
# 1   $80 total
# 2   $88 total
# 3  $164 total
# 4  $102 total

# %%
december29_df["Check-In Date"] = "12/29/2023"
december29_df["Check-Out Date"] = "12/31/2023"
december29_df = december29_df[cols]
december29_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0    12/29/2023     12/31/2023
# 1    12/29/2023     12/31/2023
# 2    12/29/2023     12/31/2023
# 3    12/29/2023     12/31/2023
# 4    12/29/2023     12/31/2023
#
#                                         Hotel Name  Advertised Price  \
# 0                                  Americana Motel  The price is $70
# 1                  Tides Motor Inn at Stehli Beach  The price is $79
# 2  Luxury Private Room in Westfield, 1 hour to NYC  The price is $79
# 3                        Days Inn by Wyndham Wayne  The price is $85
# 4                             Cozy Nights 2Bedroom  The price is $90
#
#   Total Price
# 0   $80 total
# 1   $88 total
# 2  $164 total
# 3   $97 total
# 4  $176 total

# %%
december2023_df = pd.concat([december1_df, december8_df, december15_df, december22_df, december29_df], axis=0)
december2023_df
# Out:
#     Check-In Date Check-Out Date  \
# 0       12/1/2023      12/3/2023
# 1       12/1/2023      12/3/2023
# 2       12/1/2023      12/3/2023
# 3       12/1/2023      12/3/2023
# 4       12/1/2023      12/3/2023
# ..            ...            ...
# 749    12/29/2023     12/31/2023
# 750    12/29/2023     12/31/2023
# 751    12/29/2023     12/31/2023
# 752    12/29/2023     12/31/2023
# 753    12/29/2023     12/31/2023
#
#                                          Hotel Name  Advertised Price  \
# 0                         Days Inn by Wyndham Wayne  The price is $63
# 1                   Tides Motor Inn at Stehli Beach  The price is $79
# 2           Days Inn by Wyndham Iselin / Woodbridge  The price is $89
# 3    Extended Stay America Suites Newark Woodbridge  The price is $95
# 4        Days Inn by Wyndham Nanuet / Spring Valley  The price is $96
# ..                                              ...               ...
# ...

# %%
january5_df["Check-In Date"] = "1/5/2024"
january5_df["Check-Out Date"] = "1/7/2024"
january5_df = january5_df[cols]
january5_df.head()
# Out:
#   Check-In Date Check-Out Date                                   Hotel Name  \
# 0      1/5/2024       1/7/2024                    Days Inn by Wyndham Wayne
# 1      1/5/2024       1/7/2024      Days Inn by Wyndham Iselin / Woodbridge
# 2      1/5/2024       1/7/2024              Tides Motor Inn at Stehli Beach
# 3      1/5/2024       1/7/2024                            Rodeway Inn Capri
# 4      1/5/2024       1/7/2024  Super 8 by Wyndham North Bergen NJ/NYC Area
#
#    Advertised Price Total Price
# 0  The price is $63   $72 total
# 1  The price is $78   $90 total
# 2  The price is $79   $88 total
# 3  The price is $85  $100 total
# 4  The price is $88  $104 total

# %%
january12_df["Check-In Date"] = "1/12/2024"
january12_df["Check-Out Date"] = "1/14/2024"
january12_df = january12_df[cols]
january12_df.head()
# Out:
#   Check-In Date Check-Out Date                               Hotel Name  \
# 0     1/12/2024      1/14/2024                Days Inn by Wyndham Wayne
# 1     1/12/2024      1/14/2024                       Bowery Grand Hotel
# 2     1/12/2024      1/14/2024  Days Inn by Wyndham Iselin / Woodbridge
# 3     1/12/2024      1/14/2024          Tides Motor Inn at Stehli Beach
# 4     1/12/2024      1/14/2024                         Canal Loft Hotel
#
#    Advertised Price Total Price
# 0  The price is $63   $72 total
# 1  The price is $71   $85 total
# 2  The price is $77   $89 total
# 3  The price is $79   $88 total
# 4  The price is $81  $126 total

# %%
january19_df["Check-In Date"] = "1/19/2024"
january19_df["Check-Out Date"] = "1/21/2024"
january19_df = january19_df[cols]
january19_df.head()
# Out:
#   Check-In Date Check-Out Date                               Hotel Name  \
# 0     1/19/2024      1/21/2024                Days Inn by Wyndham Wayne
# 1     1/19/2024      1/21/2024                       Bowery Grand Hotel
# 2     1/19/2024      1/21/2024  Days Inn by Wyndham Iselin / Woodbridge
# 3     1/19/2024      1/21/2024          Tides Motor Inn at Stehli Beach
# 4     1/19/2024      1/21/2024                        Rodeway Inn Capri
#
#    Advertised Price Total Price
# 0  The price is $63   $72 total
# 1  The price is $71   $85 total
# 2  The price is $77   $89 total
# 3  The price is $79   $88 total
# 4  The price is $85  $100 total

# %%
january26_df["Check-In Date"] = "1/26/2024"
january26_df["Check-Out Date"] = "1/28/2024"
january26_df = january26_df[cols]
january26_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     1/26/2024      1/28/2024
# 1     1/26/2024      1/28/2024
# 2     1/26/2024      1/28/2024
# 3     1/26/2024      1/28/2024
# 4     1/26/2024      1/28/2024
#
#                                           Hotel Name  Advertised Price  \
# 0  WE LOVE NYC: Romantic and super clean private ...  The price is $55
# 1                          Days Inn by Wyndham Wayne  The price is $63
# 2             Travelodge by Wyndham South Hackensack  The price is $64
# 3                                    Americana Motel  The price is $70
# 4                                 Bowery Grand Hotel  The price is $71
#
#   Total Price
# 0  $100 total
# 1   $72 total
# 2   $75 total
# 3   $80 total
# 4   $85 total

# %%
january2024_df = pd.concat([january5_df, january12_df, january19_df, january26_df], axis=0)
january2024_df
# Out:
#     Check-In Date Check-Out Date                                   Hotel Name  \
# 0        1/5/2024       1/7/2024                    Days Inn by Wyndham Wayne
# 1        1/5/2024       1/7/2024      Days Inn by Wyndham Iselin / Woodbridge
# 2        1/5/2024       1/7/2024              Tides Motor Inn at Stehli Beach
# 3        1/5/2024       1/7/2024                            Rodeway Inn Capri
# 4        1/5/2024       1/7/2024  Super 8 by Wyndham North Bergen NJ/NYC Area
# ..            ...            ...                                          ...
# 750     1/26/2024      1/28/2024                 Hampton Inn & Suites Yonkers
# 751     1/26/2024      1/28/2024                           Pointe Plaza Hotel
# 752     1/26/2024      1/28/2024                             The Baltic Hotel
# 753     1/26/2024      1/28/2024                                   John Hotel
# 754     1/26/2024      1/28/2024            Hotel Nyack, a JdV by Hyatt Hotel
#
# ...

# %%
february2_df["Check-In Date"] = "2/2/2024"
february2_df["Check-Out Date"] = "2/4/2024"
february2_df = february2_df[cols]
february2_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0      2/2/2024       2/4/2024
# 1      2/2/2024       2/4/2024
# 2      2/2/2024       2/4/2024
# 3      2/2/2024       2/4/2024
# 4      2/2/2024       2/4/2024
#
#                                           Hotel Name  Advertised Price  \
# 0  WE LOVE NYC: Romantic and super clean private ...  The price is $55
# 1             Travelodge by Wyndham South Hackensack  The price is $68
# 2                          Days Inn by Wyndham Wayne  The price is $70
# 3                                    Americana Motel  The price is $70
# 4            Days Inn by Wyndham Iselin / Woodbridge  The price is $71
#
#   Total Price
# 0  $100 total
# 1   $80 total
# 2   $80 total
# 3   $80 total
# 4   $81 total

# %%
february9_df["Check-In Date"] = "2/9/2024"
february9_df["Check-Out Date"] = "2/11/2024"
february9_df = february9_df[cols]
february9_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0      2/9/2024      2/11/2024
# 1      2/9/2024      2/11/2024
# 2      2/9/2024      2/11/2024
# 3      2/9/2024      2/11/2024
# 4      2/9/2024      2/11/2024
#
#                                           Hotel Name  Advertised Price  \
# 0  WE LOVE NYC: Romantic and super clean private ...  The price is $55
# 1                          Days Inn by Wyndham Wayne  The price is $70
# 2                                    Americana Motel  The price is $70
# 3            Days Inn by Wyndham Iselin / Woodbridge  The price is $71
# 4            Travelodge by Wyndham Avenel Woodbridge  The price is $72
#
#   Total Price
# 0  $100 total
# 1   $80 total
# 2   $80 total
# 3   $81 total
# 4   $83 total

# %%
february16_df["Check-In Date"] = "2/16/2024"
february16_df["Check-Out Date"] = "2/18/2024"
february16_df = february16_df[cols]
february16_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     2/16/2024      2/18/2024
# 1     2/16/2024      2/18/2024
# 2     2/16/2024      2/18/2024
# 3     2/16/2024      2/18/2024
# 4     2/16/2024      2/18/2024
#
#                                           Hotel Name  Advertised Price  \
# 0  WE LOVE NYC: Romantic and super clean private ...  The price is $55
# 1                          Days Inn by Wyndham Wayne  The price is $70
# 2                                    Americana Motel  The price is $70
# 3                       Knights Inn South Hackensack  The price is $70
# 4                                 Bowery Grand Hotel  The price is $71
#
#   Total Price
# 0  $100 total
# 1   $80 total
# 2   $80 total
# 3   $82 total
# 4   $85 total

# %%
february23_df["Check-In Date"] = "2/23/2024"
february23_df["Check-Out Date"] = "2/25/2024"
february23_df = february23_df[cols]
february23_df.head()
# Out:
#   Check-In Date Check-Out Date                               Hotel Name  \
# 0     2/23/2024      2/25/2024                Days Inn by Wyndham Wayne
# 1     2/23/2024      2/25/2024  Days Inn by Wyndham Iselin / Woodbridge
# 2     2/23/2024      2/25/2024                       Bowery Grand Hotel
# 3     2/23/2024      2/25/2024          Tides Motor Inn at Stehli Beach
# 4     2/23/2024      2/25/2024                         Canal Loft Hotel
#
#    Advertised Price Total Price
# 0  The price is $70   $80 total
# 1  The price is $71   $81 total
# 2  The price is $71   $85 total
# 3  The price is $79   $88 total
# 4  The price is $81  $126 total

# %%
february2024_df = pd.concat([february2_df, february9_df, february16_df, february23_df], axis=0)
february2024_df
# Out:
#     Check-In Date Check-Out Date  \
# 0        2/2/2024       2/4/2024
# 1        2/2/2024       2/4/2024
# 2        2/2/2024       2/4/2024
# 3        2/2/2024       2/4/2024
# 4        2/2/2024       2/4/2024
# ..            ...            ...
# 742     2/23/2024      2/25/2024
# 743     2/23/2024      2/25/2024
# 744     2/23/2024      2/25/2024
# 745     2/23/2024      2/25/2024
# 746     2/23/2024      2/25/2024
#
#                                             Hotel Name  Advertised Price  \
# 0    WE LOVE NYC: Romantic and super clean private ...  The price is $55
# 1               Travelodge by Wyndham South Hackensack  The price is $68
# 2                            Days Inn by Wyndham Wayne  The price is $70
# 3                                      Americana Motel  The price is $70
# 4              Days Inn by Wyndham Iselin / Woodbridge  The price is $71
# ..                                                 ...               ...
# ...

# %%
march1_df["Check-In Date"] = "3/1/2024"
march1_df["Check-Out Date"] = "3/3/2024"
march1_df = march1_df[cols]
march1_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0      3/1/2024       3/3/2024
# 1      3/1/2024       3/3/2024
# 2      3/1/2024       3/3/2024
# 3      3/1/2024       3/3/2024
# 4      3/1/2024       3/3/2024
#
#                                           Hotel Name  Advertised Price  \
# 0  WE LOVE NYC: Romantic and super clean private ...  The price is $55
# 1                                    Americana Motel  The price is $70
# 2                       Knights Inn South Hackensack  The price is $70
# 3            Travelodge by Wyndham Avenel Woodbridge  The price is $72
# 4             Travelodge by Wyndham South Hackensack  The price is $72
#
#   Total Price
# 0  $100 total
# 1   $80 total
# 2   $82 total
# 3   $83 total
# 4   $85 total

# %%
march8_df["Check-In Date"] = "3/8/2024"
march8_df["Check-Out Date"] = "3/10/2024"
march8_df = march8_df[cols]
march8_df.head()
# Out:
#   Check-In Date Check-Out Date                               Hotel Name  \
# 0      3/8/2024      3/10/2024                Days Inn by Wyndham Wayne
# 1      3/8/2024      3/10/2024  Days Inn by Wyndham Iselin / Woodbridge
# 2      3/8/2024      3/10/2024          Tides Motor Inn at Stehli Beach
# 3      3/8/2024      3/10/2024                        Rodeway Inn Capri
# 4      3/8/2024      3/10/2024                       Bowery Grand Hotel
#
#    Advertised Price Total Price
# 0  The price is $77   $88 total
# 1  The price is $77   $89 total
# 2  The price is $79   $88 total
# 3  The price is $85  $100 total
# 4  The price is $89  $106 total

# %%
march15_df["Check-In Date"] = "3/15/2024"
march15_df["Check-Out Date"] = "3/17/2024"
march15_df = march15_df[cols]
march15_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     3/15/2024      3/17/2024
# 1     3/15/2024      3/17/2024
# 2     3/15/2024      3/17/2024
# 3     3/15/2024      3/17/2024
# 4     3/15/2024      3/17/2024
#
#                                           Hotel Name  Advertised Price  \
# 0  WE LOVE NYC: Romantic and super clean private ...  The price is $55
# 1                                    Americana Motel  The price is $70
# 2                       Knights Inn South Hackensack  The price is $70
# 3            Travelodge by Wyndham Avenel Woodbridge  The price is $72
# 4             Travelodge by Wyndham South Hackensack  The price is $76
#
#   Total Price
# 0  $100 total
# 1   $80 total
# 2   $82 total
# 3   $83 total
# 4   $90 total

# %%
march22_df["Check-In Date"] = "3/22/2024"
march22_df["Check-Out Date"] = "3/24/2024"
march22_df = march22_df[cols]
march22_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     3/22/2024      3/24/2024
# 1     3/22/2024      3/24/2024
# 2     3/22/2024      3/24/2024
# 3     3/22/2024      3/24/2024
# 4     3/22/2024      3/24/2024
#
#                                           Hotel Name  Advertised Price  \
# 0  WE LOVE NYC: Romantic and super clean private ...  The price is $55
# 1            Travelodge by Wyndham Avenel Woodbridge  The price is $68
# 2                                    Americana Motel  The price is $70
# 3                       Knights Inn South Hackensack  The price is $70
# 4             Travelodge by Wyndham South Hackensack  The price is $76
#
#   Total Price
# 0  $100 total
# 1   $78 total
# 2   $80 total
# 3   $82 total
# 4   $90 total

# %%
march29_df["Check-In Date"] = "3/29/2024"
march29_df["Check-Out Date"] = "3/31/2024"
march29_df = march29_df[cols]
march29_df.head()
# Out:
#   Check-In Date Check-Out Date                       Hotel Name  \
# 0     3/29/2024      3/31/2024        Days Inn by Wyndham Wayne
# 1     3/29/2024      3/31/2024  Tides Motor Inn at Stehli Beach
# 2     3/29/2024      3/31/2024                Rodeway Inn Capri
# 3     3/29/2024      3/31/2024               Bowery Grand Hotel
# 4     3/29/2024      3/31/2024    Ramada by Wyndham East Orange
#
#    Advertised Price Total Price
# 0  The price is $77   $88 total
# 1  The price is $79   $88 total
# 2  The price is $85  $100 total
# 3  The price is $89  $106 total
# 4  The price is $93  $104 total

# %%
march2024_df = pd.concat([march1_df, march8_df, march15_df, march22_df, march29_df], axis=0)
march2024_df
# Out:
#     Check-In Date Check-Out Date  \
# 0        3/1/2024       3/3/2024
# 1        3/1/2024       3/3/2024
# 2        3/1/2024       3/3/2024
# 3        3/1/2024       3/3/2024
# 4        3/1/2024       3/3/2024
# ..            ...            ...
# 742     3/29/2024      3/31/2024
# 743     3/29/2024      3/31/2024
# 744     3/29/2024      3/31/2024
# 745     3/29/2024      3/31/2024
# 746     3/29/2024      3/31/2024
#
#                                             Hotel Name  Advertised Price  \
# 0    WE LOVE NYC: Romantic and super clean private ...  The price is $55
# 1                                      Americana Motel  The price is $70
# 2                         Knights Inn South Hackensack  The price is $70
# 3              Travelodge by Wyndham Avenel Woodbridge  The price is $72
# 4               Travelodge by Wyndham South Hackensack  The price is $72
# ..                                                 ...               ...
# ...

# %%
april5_df["Check-In Date"] = "4/5/2024"
april5_df["Check-Out Date"] = "4/7/2024"
april5_df = april5_df[cols]
april5_df.head()
# Out:
#   Check-In Date Check-Out Date                                  Hotel Name  \
# 0      4/5/2024       4/7/2024                           Rodeway Inn Capri
# 1      4/5/2024       4/7/2024  Days Inn by Wyndham Nanuet / Spring Valley
# 2      4/5/2024       4/7/2024                   Days Inn by Wyndham Wayne
# 3      4/5/2024       4/7/2024     Days Inn by Wyndham Iselin / Woodbridge
# 4      4/5/2024       4/7/2024               Ramada by Wyndham East Orange
#
#    Advertised Price Total Price
# 0  The price is $85  $100 total
# 1  The price is $85   $95 total
# 2  The price is $86   $98 total
# 3  The price is $89  $102 total
# 4  The price is $93  $104 total

# %%
april12_df["Check-In Date"] = "4/12/2024"
april12_df["Check-Out Date"] = "4/14/2024"
april12_df = april12_df[cols]
april12_df.head()
# Out:
#   Check-In Date Check-Out Date                                  Hotel Name  \
# 0     4/12/2024      4/14/2024                   Days Inn by Wyndham Wayne
# 1     4/12/2024      4/14/2024                           Rodeway Inn Capri
# 2     4/12/2024      4/14/2024  Days Inn by Wyndham Nanuet / Spring Valley
# 3     4/12/2024      4/14/2024     Days Inn by Wyndham Iselin / Woodbridge
# 4     4/12/2024      4/14/2024               Ramada by Wyndham East Orange
#
#    Advertised Price Total Price
# 0  The price is $84   $96 total
# 1  The price is $85  $100 total
# 2  The price is $85   $95 total
# 3  The price is $87  $100 total
# 4  The price is $93  $104 total

# %%
april19_df["Check-In Date"] = "4/19/2024"
april19_df["Check-Out Date"] = "4/21/2024"
april19_df = april19_df[cols]
april19_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     4/19/2024      4/21/2024
# 1     4/19/2024      4/21/2024
# 2     4/19/2024      4/21/2024
# 3     4/19/2024      4/21/2024
# 4     4/19/2024      4/21/2024
#
#                                           Hotel Name  Advertised Price  \
# 0  WE LOVE NYC: Romantic and super clean private ...  The price is $55
# 1                                    Americana Motel  The price is $70
# 2            Travelodge by Wyndham Avenel Woodbridge  The price is $72
# 3         Days Inn by Wyndham Jersey City / NYC Area  The price is $72
# 4             Travelodge by Wyndham South Hackensack  The price is $76
#
#   Total Price
# 0  $100 total
# 1   $80 total
# 2   $83 total
# 3   $84 total
# 4   $89 total

# %%
april26_df["Check-In Date"] = "4/26/2024"
april26_df["Check-Out Date"] = "4/28/2024"
april26_df = april26_df[cols]
april26_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     4/26/2024      4/28/2024
# 1     4/26/2024      4/28/2024
# 2     4/26/2024      4/28/2024
# 3     4/26/2024      4/28/2024
# 4     4/26/2024      4/28/2024
#
#                                           Hotel Name  Advertised Price  \
# 0  WE LOVE NYC: Romantic and super clean private ...  The price is $55
# 1                                    Americana Motel  The price is $70
# 2            Travelodge by Wyndham Avenel Woodbridge  The price is $72
# 3         Days Inn by Wyndham Jersey City / NYC Area  The price is $72
# 4             Travelodge by Wyndham South Hackensack  The price is $76
#
#   Total Price
# 0  $100 total
# 1   $80 total
# 2   $83 total
# 3   $84 total
# 4   $89 total

# %%
april2024_df = pd.concat([april5_df, april12_df, april19_df, april26_df], axis=0)
april2024_df
# Out:
#     Check-In Date Check-Out Date                                  Hotel Name  \
# 0        4/5/2024       4/7/2024                           Rodeway Inn Capri
# 1        4/5/2024       4/7/2024  Days Inn by Wyndham Nanuet / Spring Valley
# 2        4/5/2024       4/7/2024                   Days Inn by Wyndham Wayne
# 3        4/5/2024       4/7/2024     Days Inn by Wyndham Iselin / Woodbridge
# 4        4/5/2024       4/7/2024               Ramada by Wyndham East Orange
# ..            ...            ...                                         ...
# 751     4/26/2024      4/28/2024      Comfort Inn & Suites LaGuardia Airport
# 752     4/26/2024      4/28/2024                            The Baltic Hotel
# 753     4/26/2024      4/28/2024                         Royal Regency Hotel
# 754     4/26/2024      4/28/2024                                  John Hotel
# 755     4/26/2024      4/28/2024                        Comfort Inn Brooklyn
#
#      Advertised Price      Total Price
# ...

# %%
may3_df["Check-In Date"] = "5/3/2024"
may3_df["Check-Out Date"] = "5/5/2024"
may3_df = may3_df[cols]
may3_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0      5/3/2024       5/5/2024
# 1      5/3/2024       5/5/2024
# 2      5/3/2024       5/5/2024
# 3      5/3/2024       5/5/2024
# 4      5/3/2024       5/5/2024
#
#                                           Hotel Name  Advertised Price  \
# 0  WE LOVE NYC: Romantic and super clean private ...  The price is $55
# 1            Days Inn by Wyndham Iselin / Woodbridge  The price is $68
# 2                                    Americana Motel  The price is $70
# 3         Days Inn by Wyndham Jersey City / NYC Area  The price is $72
# 4             Travelodge by Wyndham South Hackensack  The price is $76
#
#   Total Price
# 0  $100 total
# 1   $78 total
# 2   $80 total
# 3   $84 total
# 4   $89 total

# %%
may10_df["Check-In Date"] = "5/10/2024"
may10_df["Check-Out Date"] = "5/12/2024"
may10_df = may10_df[cols]
may10_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     5/10/2024      5/12/2024
# 1     5/10/2024      5/12/2024
# 2     5/10/2024      5/12/2024
# 3     5/10/2024      5/12/2024
# 4     5/10/2024      5/12/2024
#
#                                           Hotel Name  Advertised Price  \
# 0  WE LOVE NYC: Romantic and super clean private ...  The price is $55
# 1                                    Americana Motel  The price is $70
# 2            Travelodge by Wyndham Avenel Woodbridge  The price is $72
# 3         Days Inn by Wyndham Jersey City / NYC Area  The price is $72
# 4             Travelodge by Wyndham South Hackensack  The price is $76
#
#   Total Price
# 0  $100 total
# 1   $80 total
# 2   $83 total
# 3   $84 total
# 4   $89 total

# %%
may17_df["Check-In Date"] = "5/17/2024"
may17_df["Check-Out Date"] = "5/19/2024"
may17_df = may17_df[cols]
may17_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     5/17/2024      5/19/2024
# 1     5/17/2024      5/19/2024
# 2     5/17/2024      5/19/2024
# 3     5/17/2024      5/19/2024
# 4     5/17/2024      5/19/2024
#
#                                           Hotel Name  Advertised Price  \
# 0            Travelodge by Wyndham Avenel Woodbridge  The price is $48
# 1  WE LOVE NYC: Romantic and super clean private ...  The price is $55
# 2             Travelodge by Wyndham South Hackensack  The price is $76
# 3    Luxury Private Room in Westfield, 1 hour to NYC  The price is $79
# 4  ⭐️ Best Studio/RV To Visit NYC✈️EWR Airport-Fr...  The price is $79
#
#   Total Price
# 0   $55 total
# 1  $100 total
# 2   $89 total
# 3  $164 total
# 4  $251 total

# %%
may24_df["Check-In Date"] = "5/24/2024"
may24_df["Check-Out Date"] = "5/26/2024"
may24_df = may24_df[cols]
may24_df.head()
# Out:
#   Check-In Date Check-Out Date  \
# 0     5/24/2024      5/26/2024
# 1     5/24/2024      5/26/2024
# 2     5/24/2024      5/26/2024
# 3     5/24/2024      5/26/2024
# 4     5/24/2024      5/26/2024
#
#                                           Hotel Name  Advertised Price  \
# 0  WE LOVE NYC: Romantic and super clean private ...  The price is $55
# 1    Luxury Private Room in Westfield, 1 hour to NYC  The price is $79
# 2  ⭐️ Best Studio/RV To Visit NYC✈️EWR Airport-Fr...  The price is $79
# 3           Charming Apartment in Quiet Neighborhood  The price is $98
# 4                          Luxe Autos Exotic Rentals  The price is $99
#
#   Total Price
# 0  $100 total
# 1  $164 total
# 2  $251 total
# 3  $158 total
# 4  $131 total

# %%
may2024_df = pd.concat([may3_df, may10_df, may17_df, may24_df], axis=0)
may2024_df
# Out:
#     Check-In Date Check-Out Date  \
# 0        5/3/2024       5/5/2024
# 1        5/3/2024       5/5/2024
# 2        5/3/2024       5/5/2024
# 3        5/3/2024       5/5/2024
# 4        5/3/2024       5/5/2024
# ..            ...            ...
# 751     5/24/2024      5/26/2024
# 752     5/24/2024      5/26/2024
# 753     5/24/2024      5/26/2024
# 754     5/24/2024      5/26/2024
# 755     5/24/2024      5/26/2024
#
#                                             Hotel Name  Advertised Price  \
# 0    WE LOVE NYC: Romantic and super clean private ...  The price is $55
# 1              Days Inn by Wyndham Iselin / Woodbridge  The price is $68
# 2                                      Americana Motel  The price is $70
# 3           Days Inn by Wyndham Jersey City / NYC Area  The price is $72
# 4               Travelodge by Wyndham South Hackensack  The price is $76
# ..                                                 ...               ...
# ...

# %%
hotel_prices_all = pd.concat([june2023_df, july2023_df, august2023_df, september2023_df, october2023_df, november2023_df, 
                             december2023_df, january2024_df, february2024_df, march2024_df, april2024_df, may2024_df], axis=0)
hotel_prices_all
# Out:
#     Check-In Date Check-Out Date  \
# 0        6/2/2023       6/4/2023
# 1        6/2/2023       6/4/2023
# 2        6/2/2023       6/4/2023
# 3        6/2/2023       6/4/2023
# 4        6/2/2023       6/4/2023
# ..            ...            ...
# 751     5/24/2024      5/26/2024
# 752     5/24/2024      5/26/2024
# 753     5/24/2024      5/26/2024
# 754     5/24/2024      5/26/2024
# 755     5/24/2024      5/26/2024
#
#                                          Hotel Name  Advertised Price  \
# 0                          31 Street Broadway Hotel  The price is $69
# 1                                   Americana Motel  The price is $70
# 2                         Days Inn by Wyndham Wayne  The price is $91
# 3                Quality Inn Wayne - Fairfield Area  The price is $95
# 4         Americas Best Value Inn Avenel Woodbridge  The price is $99
# ..                                              ...               ...
# ...

# %%
hotel_clean = hotel_prices_all.copy()
hotel_clean
# Out:
#     Check-In Date Check-Out Date  \
# 0        6/2/2023       6/4/2023
# 1        6/2/2023       6/4/2023
# 2        6/2/2023       6/4/2023
# 3        6/2/2023       6/4/2023
# 4        6/2/2023       6/4/2023
# ..            ...            ...
# 751     5/24/2024      5/26/2024
# 752     5/24/2024      5/26/2024
# 753     5/24/2024      5/26/2024
# 754     5/24/2024      5/26/2024
# 755     5/24/2024      5/26/2024
#
#                                          Hotel Name  Advertised Price  \
# 0                          31 Street Broadway Hotel  The price is $69
# 1                                   Americana Motel  The price is $70
# 2                         Days Inn by Wyndham Wayne  The price is $91
# 3                Quality Inn Wayne - Fairfield Area  The price is $95
# 4         Americas Best Value Inn Avenel Woodbridge  The price is $99
# ..                                              ...               ...
# ...

# %%
p = "(\W\d{1,})"
price = hotel_clean["Advertised Price"].str.extract(p)
hotel_clean["Advertised Price ($)"] = price
hotel_clean
# Out:
# /var/folders/p1/75d6qxbd65v17kwgc_pn1k7w0000gn/T/ipykernel_10277/3550586163.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_clean["Advertised Price ($)"] = price
#     Check-In Date Check-Out Date  Advertised Price      Total Price  \
# 0        6/2/2023       6/4/2023  The price is $69       $277 total
# 1        6/2/2023       6/4/2023  The price is $70        $80 total
# 2        6/2/2023       6/4/2023  The price is $91       $104 total
# 3        6/2/2023       6/4/2023  The price is $95       $108 total
# 4        6/2/2023       6/4/2023  The price is $99       $113 total
# ..            ...            ...               ...              ...
# 751     5/24/2024      5/26/2024   We are sold out  We are sold out
# ...

# %%
p = "(\W\d{1,})"
t_price = hotel_clean["Total Price"].str.extract(p)
hotel_clean["Total Price ($)"] = t_price
hotel_clean
# Out:
# /var/folders/p1/75d6qxbd65v17kwgc_pn1k7w0000gn/T/ipykernel_10277/1425598098.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_clean["Total Price ($)"] = t_price
#     Check-In Date Check-Out Date  Advertised Price      Total Price  \
# 0        6/2/2023       6/4/2023  The price is $69       $277 total
# 1        6/2/2023       6/4/2023  The price is $70        $80 total
# 2        6/2/2023       6/4/2023  The price is $91       $104 total
# 3        6/2/2023       6/4/2023  The price is $95       $108 total
# 4        6/2/2023       6/4/2023  The price is $99       $113 total
# ..            ...            ...               ...              ...
# 751     5/24/2024      5/26/2024   We are sold out  We are sold out
# ...

# %%
clean_cols = ["Check-In Date", "Check-Out Date", "Advertised Price", "Total Price", "Advertised Price ($)", "Total Price ($)"]

# %%
hotel_clean = hotel_clean[clean_cols]
hotel_clean
# Out:
#     Check-In Date Check-Out Date  Advertised Price      Total Price  \
# 0        6/2/2023       6/4/2023  The price is $69       $277 total
# 1        6/2/2023       6/4/2023  The price is $70        $80 total
# 2        6/2/2023       6/4/2023  The price is $91       $104 total
# 3        6/2/2023       6/4/2023  The price is $95       $108 total
# 4        6/2/2023       6/4/2023  The price is $99       $113 total
# ..            ...            ...               ...              ...
# 751     5/24/2024      5/26/2024   We are sold out  We are sold out
# 752     5/24/2024      5/26/2024   We are sold out  We are sold out
# 753     5/24/2024      5/26/2024   We are sold out  We are sold out
# 754     5/24/2024      5/26/2024   We are sold out  We are sold out
# 755     5/24/2024      5/26/2024   We are sold out  We are sold out
#
#     Advertised Price ($) Total Price ($)
# 0                    $69            $277
# 1                    $70             $80
# ...

# %%
hotel_clean.to_csv("HotelData/hotel_prices_FAT_table_clean.csv", index=False, header=True)

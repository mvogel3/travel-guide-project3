# %%
# Importing Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup

# %%
browser = Browser('chrome')

# %%
url = 'https://www.expedia.com/Hotel-Search?HotelID=3016212&adults=2&children=&destination=New%20York%2C%20New%20York%2C%20United%20States%20of%20America&endDate=2023-08-02&gclid=CjwKCAjwpayjBhAnEiwA-7ena7JGaI1rwCkOUycQoEp0ICRA_jkQo7Qt2Wwm4iOrBE-_4GP68HEzBRoC6xIQAvD_BwE&latLong=&locale=en_US&mapBounds=&pwaDialog=&regionId=2621&semcid=US.UB.GOOGLE.PT-c-EN.HOTEL&semdtl=a115093754954.b1127871358663.g1kwd-42777028833.l1.e1c.m1CjwKCAjwpayjBhAnEiwA-7ena7JGaI1rwCkOUycQoEp0ICRA_jkQo7Qt2Wwm4iOrBE-_4GP68HEzBRoC6xIQAvD_BwE.r14d4f421864e74f5bf75be17391f1a3135e350e186a47a1456f6c4f1617a2988c.c10RNuppwrQ5tvtmka9Z9sWg.j19032180.k1.d1558118514604.h1e.i1.n1.o1.p1.q1.s1.t1.x1.f1.u1.v1.w1&siteid=1&sort=PRICE_LOW_TO_HIGH&startDate=2023-08-01&theme=&useRewards=false&userIntent='
browser.visit(url)

# %%
# Creating a Beautiful Soup object
html = browser.html
soup = soup(html, 'html.parser')

# %%
price = soup.find_all('div', class_="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden")

# %%
price
# Out:
# [<div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $79</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $81</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $93</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $83</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $85</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $86</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $98</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $88</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $89</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $89</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $89</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $90</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $90</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $90</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $90</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $90</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $93</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $94</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $95</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $95</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $95</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $95</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $109</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $98</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $99</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $99</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $99</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $99</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $99</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $119</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $101</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $101</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $102</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $102</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $102</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $102</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $104</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $107</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $108</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $121</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $108</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $109</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $109</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $109</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $110</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $114</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $114</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $114</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $116</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $116</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $117</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $131</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $118</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $118</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $118</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $119</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $119</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $119</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $119</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $119</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $119</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $119</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $120</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $120</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $120</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $121</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $122</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $123</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $125</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $125</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $125</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $148</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $126</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $140</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $126</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $126</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $126</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $127</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $127</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $127</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $128</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $129</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $129</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $130</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $130</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $132</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $133</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $134</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $135</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $135</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $169</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $135</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $136</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $136</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $136</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $137</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $155</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $138</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $139</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $139</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $139</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $139</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $139</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $142</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $178</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $142</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $144</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $144</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $169</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $144</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $144</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $144</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $145</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $161</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $145</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $146</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $147</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $147</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $148</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $148</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $148</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $149</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $175</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $149</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $149</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $149</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $149</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $149</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $149</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $149</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $149</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $159</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $149</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $187</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $150</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $150</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $150</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $152</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $152</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $169</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $152</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $169</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $152</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $169</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $152</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $152</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $152</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $152</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $152</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $152</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $152</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $152</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $153</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $153</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $154</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $154</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $171</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $154</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $155</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $156</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $156</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $157</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $157</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $157</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $157</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $158</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $158</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $158</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $159</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $159</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $159</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $159</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $199</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $159</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $177</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $159</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $160</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $160</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $189</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $161</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $189</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $161</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $161</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $179</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $161</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $161</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $161</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $161</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $179</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $161</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $161</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $163</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $163</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $164</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $164</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $165</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $165</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $184</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $166</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $166</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $166</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $175</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $166</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $166</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $166</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $168</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $168</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $169</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $169</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $169</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $169</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $169</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $169</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $169</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $169</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $169</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $169</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $170</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $170</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $189</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $170</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $170</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $170</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $170</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $170</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $171</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $171</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $203</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $173</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $173</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $173</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $173</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $174</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $174</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $174</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $175</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $269</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $175</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $175</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $176</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $176</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $176</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $177</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $178</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $188</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $179</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $179</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $179</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $179</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $179</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $179</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $179</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $179</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $179</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $179</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $180</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $214</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $180</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $180</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $180</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $180</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $203</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $182</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $182</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $182</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $183</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $183</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $184</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $207</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $186</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $186</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $209</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $187</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $187</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $187</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $187</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $188</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $188</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $189</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $189</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $189</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $191</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $191</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $192</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $241</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $193</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $193</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $194</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $194</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $194</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $195</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $195</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $279</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $195</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $218</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $196</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $197</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $197</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $219</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $197</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $198</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $199</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $199</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $199</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $199</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $199</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $199</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $199</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $199</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $199</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $200</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $201</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $201</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $202</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $249</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $202</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $289</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $202</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $203</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $215</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $204</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $204</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $204</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $204</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $204</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $206</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $257</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $206</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $206</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $229</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $206</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $206</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $245</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $208</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $209</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $209</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $209</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $209</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $209</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $209</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $234</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $209</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $238</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $209</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $210</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $211</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $229</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $211</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $211</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $249</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $212</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $249</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $212</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $236</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $212</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $250</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $213</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $213</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $215</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $239</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $215</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $229</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $215</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $217</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $255</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $217</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $217</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $218</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $218</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $219</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $219</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $220</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $220</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $220</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $220</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $260</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $221</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $260</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $221</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $221</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $279</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $223</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $249</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $224</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $224</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $224</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $224</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $224</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $224</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $299</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $224</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $224</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $265</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $225</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $226</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $227</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $254</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $227</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $229</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $269</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $229</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $229</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $229</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $229</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $229</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $255</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $230</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $255</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $230</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $230</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $230</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $230</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $233</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $233</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $234</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $235</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $235</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $236</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $237</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $237</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $237</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $237</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $237</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $237</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $237</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $279</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $237</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $237</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $238</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $317</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $238</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $238</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $239</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $239</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $239</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $299</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $239</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $239</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $275</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $239</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $240</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $240</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $241</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $242</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $269</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $242</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $269</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $242</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $242</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $243</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $270</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $243</div>,
# ...
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $552</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $359</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $359</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $399</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $359</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $360</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $361</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $362</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $363</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $364</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $608</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $365</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $365</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $366</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $367</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $368</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $369</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $373</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $376</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $377</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $377</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $381</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $382</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $384</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $384</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $385</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $386</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $389</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $389</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $390</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $391</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $392</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $396</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $398</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $399</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $399</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $399</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $399</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $399</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $401</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $404</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $404</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $404</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $449</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $404</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $405</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $407</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $585</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $409</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $412</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $412</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $415</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $416</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $419</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $419</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $422</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $424</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $425</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $429</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $431</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $433</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $439</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $446</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $448</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $449</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $449</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $449</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $454</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $458</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $465</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $465</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $518</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $466</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $469</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $474</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $474</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $474</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $474</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $679</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $475</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $972</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $476</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $564</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $479</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $650</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $488</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $489</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $493</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $494</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $495</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $501</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $512</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $525</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $529</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $534</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $535</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $536</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $547</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $548</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $549</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $565</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $813</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $569</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $571</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $574</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $579</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $585</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $589</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $591</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $596</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $599</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $605</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $608</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $609</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $633</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $745</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $633</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $764</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $649</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $669</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $695</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $699</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $699</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $699</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $718</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $741</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $741</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $750</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $850</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $765</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $785</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $795</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $795</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $806</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $895</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $806</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $825</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $825</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $835</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price was $895</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $850</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $854</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $870</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $878</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $895</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $896</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $985</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $1,050</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $1,505</div>,
#  <div class="uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden">The price is $9,999</div>]

# %%
for p in price:
    print(p.text)
# Out:
# The price is $79
# The price is $81
# The price was $93
# The price is $83
# The price is $85
# The price is $86
# The price was $98
# The price is $88
# The price is $89
# The price is $89
# The price is $89
# The price is $90
# The price is $90
# The price is $90
# The price is $90
# The price is $90
# The price is $93
# The price is $94
# The price is $95
# The price is $95
# The price is $95
# The price is $95
# The price was $109
# The price is $98
# The price is $99
# The price is $99
# The price is $99
# The price is $99
# The price is $99
# The price was $119
# The price is $101
# The price is $101
# The price is $102
# The price is $102
# The price is $102
# The price is $102
# The price is $104
# The price is $107
# The price is $108
# The price was $121
# The price is $108
# The price is $109
# The price is $109
# The price is $109
# The price is $110
# The price is $114
# The price is $114
# The price is $114
# The price is $116
# The price is $116
# The price is $117
# The price was $131
# The price is $118
# The price is $118
# The price is $118
# The price is $119
# The price is $119
# The price is $119
# The price is $119
# The price is $119
# The price is $119
# The price is $119
# The price is $120
# The price is $120
# The price is $120
# The price is $121
# The price is $122
# The price is $123
# The price is $125
# The price is $125
# The price is $125
# The price was $148
# The price is $126
# The price was $140
# The price is $126
# The price is $126
# The price is $126
# The price is $127
# The price is $127
# The price is $127
# The price is $128
# The price is $129
# The price is $129
# The price is $130
# The price is $130
# The price is $132
# The price is $133
# The price is $134
# The price is $135
# The price is $135
# The price was $169
# The price is $135
# The price is $136
# The price is $136
# The price is $136
# The price is $137
# The price was $155
# The price is $138
# The price is $139
# The price is $139
# The price is $139
# The price is $139
# The price is $139
# The price is $142
# The price was $178
# The price is $142
# The price is $144
# The price is $144
# The price was $169
# The price is $144
# The price is $144
# The price is $144
# The price is $145
# The price was $161
# The price is $145
# The price is $146
# The price is $147
# The price is $147
# The price is $148
# The price is $148
# The price is $148
# The price is $149
# The price was $175
# The price is $149
# The price is $149
# The price is $149
# The price is $149
# The price is $149
# The price is $149
# The price is $149
# The price is $149
# The price was $159
# The price is $149
# The price was $187
# The price is $150
# The price is $150
# The price is $150
# The price is $152
# The price is $152
# The price was $169
# The price is $152
# The price was $169
# The price is $152
# The price was $169
# The price is $152
# The price is $152
# The price is $152
# The price is $152
# The price is $152
# The price is $152
# The price is $152
# The price is $152
# The price is $153
# The price is $153
# The price is $154
# The price is $154
# The price was $171
# The price is $154
# The price is $155
# The price is $156
# The price is $156
# The price is $157
# The price is $157
# The price is $157
# The price is $157
# The price is $158
# The price is $158
# The price is $158
# The price is $159
# The price is $159
# The price is $159
# The price is $159
# The price was $199
# The price is $159
# The price was $177
# The price is $159
# The price is $160
# The price is $160
# The price was $189
# The price is $161
# The price was $189
# The price is $161
# The price is $161
# The price was $179
# The price is $161
# The price is $161
# The price is $161
# The price is $161
# The price was $179
# The price is $161
# The price is $161
# The price is $163
# The price is $163
# The price is $164
# The price is $164
# The price is $165
# The price is $165
# The price was $184
# The price is $166
# The price is $166
# The price is $166
# The price was $175
# The price is $166
# The price is $166
# The price is $166
# The price is $168
# The price is $168
# The price is $169
# The price is $169
# The price is $169
# The price is $169
# The price is $169
# The price is $169
# The price is $169
# The price is $169
# The price is $169
# The price is $169
# The price is $170
# The price is $170
# The price was $189
# The price is $170
# The price is $170
# The price is $170
# The price is $170
# The price is $170
# The price is $171
# The price is $171
# The price was $203
# The price is $173
# The price is $173
# The price is $173
# The price is $173
# The price is $174
# The price is $174
# The price is $174
# The price is $175
# The price was $269
# The price is $175
# The price is $175
# The price is $176
# The price is $176
# The price is $176
# The price is $177
# The price is $178
# The price was $188
# The price is $179
# The price is $179
# The price is $179
# The price is $179
# The price is $179
# The price is $179
# The price is $179
# The price is $179
# The price is $179
# The price is $179
# The price is $180
# The price was $214
# The price is $180
# The price is $180
# The price is $180
# The price is $180
# The price was $203
# The price is $182
# The price is $182
# The price is $182
# The price is $183
# The price is $183
# The price is $184
# The price was $207
# The price is $186
# The price is $186
# The price was $209
# The price is $187
# The price is $187
# The price is $187
# The price is $187
# The price is $188
# The price is $188
# The price is $189
# The price is $189
# The price is $189
# The price is $191
# The price is $191
# The price is $192
# The price was $241
# The price is $193
# The price is $193
# The price is $194
# The price is $194
# The price is $194
# The price is $195
# The price is $195
# The price was $279
# The price is $195
# The price was $218
# The price is $196
# The price is $197
# The price is $197
# The price was $219
# The price is $197
# The price is $198
# The price is $199
# The price is $199
# The price is $199
# The price is $199
# The price is $199
# The price is $199
# The price is $199
# The price is $199
# The price is $199
# The price is $200
# The price is $201
# The price is $201
# The price is $202
# The price was $249
# The price is $202
# The price was $289
# The price is $202
# The price is $203
# The price was $215
# The price is $204
# The price is $204
# The price is $204
# The price is $204
# The price is $204
# The price is $206
# The price was $257
# The price is $206
# The price is $206
# The price was $229
# The price is $206
# The price is $206
# The price was $245
# The price is $208
# The price is $209
# The price is $209
# The price is $209
# The price is $209
# The price is $209
# The price is $209
# The price was $234
# The price is $209
# The price was $238
# The price is $209
# The price is $210
# The price is $211
# The price was $229
# The price is $211
# The price is $211
# The price was $249
# The price is $212
# The price was $249
# The price is $212
# The price was $236
# The price is $212
# The price was $250
# The price is $213
# The price is $213
# The price is $215
# The price was $239
# The price is $215
# The price was $229
# The price is $215
# The price is $217
# The price was $255
# The price is $217
# The price is $217
# The price is $218
# The price is $218
# The price is $219
# The price is $219
# The price is $220
# The price is $220
# The price is $220
# The price is $220
# The price was $260
# The price is $221
# The price was $260
# The price is $221
# The price is $221
# The price was $279
# The price is $223
# The price was $249
# The price is $224
# The price is $224
# The price is $224
# The price is $224
# The price is $224
# The price is $224
# The price was $299
# The price is $224
# The price is $224
# The price was $265
# The price is $225
# The price is $226
# The price is $227
# The price was $254
# The price is $227
# The price is $229
# The price was $269
# The price is $229
# The price is $229
# The price is $229
# The price is $229
# The price is $229
# The price was $255
# The price is $230
# The price was $255
# The price is $230
# The price is $230
# The price is $230
# The price is $230
# The price is $233
# The price is $233
# The price is $234
# The price is $235
# The price is $235
# The price is $236
# The price is $237
# The price is $237
# The price is $237
# The price is $237
# The price is $237
# The price is $237
# The price is $237
# The price was $279
# The price is $237
# The price is $237
# The price is $238
# The price was $317
# The price is $238
# The price is $238
# The price is $239
# The price is $239
# The price is $239
# The price was $299
# The price is $239
# The price is $239
# The price was $275
# The price is $239
# The price is $240
# The price is $240
# The price is $241
# The price is $242
# The price was $269
# The price is $242
# The price was $269
# The price is $242
# The price is $242
# The price is $243
# The price was $270
# The price is $243
# The price was $305
# The price is $244
# The price is $245
# The price was $285
# The price is $245
# The price is $245
# The price is $246
# The price is $246
# The price is $246
# The price was $260
# The price is $247
# The price is $248
# The price is $248
# The price is $249
# The price is $249
# The price is $249
# The price is $250
# The price is $250
# The price is $250
# The price is $250
# The price is $250
# The price is $250
# The price was $295
# The price is $251
# The price is $251
# The price was $279
# The price is $251
# The price was $265
# The price is $252
# The price is $254
# The price is $254
# The price is $254
# The price was $299
# The price is $254
# The price was $299
# The price is $254
# The price is $254
# The price was $289
# The price is $254
# The price is $254
# The price was $319
# The price is $255
# The price is $257
# The price is $257
# The price is $257
# The price is $257
# The price is $257
# The price is $257
# The price is $257
# The price is $258
# The price is $258
# The price is $259
# The price is $259
# The price is $259
# The price is $259
# The price is $259
# The price is $259
# The price is $259
# The price was $398
# The price is $259
# The price is $260
# The price is $260
# The price was $289
# The price is $260
# The price is $261
# The price is $262
# The price is $263
# The price was $309
# The price is $263
# The price is $263
# The price is $263
# The price is $263
# The price is $263
# The price is $263
# The price is $264
# The price is $265
# The price is $265
# The price is $265
# The price is $269
# The price is $269
# The price is $269
# The price is $269
# The price is $269
# The price is $269
# The price is $269
# The price is $269
# The price is $269
# The price is $269
# The price is $269
# The price is $269
# The price is $269
# The price is $269
# The price was $299
# The price is $269
# The price was $299
# The price is $269
# The price is $269
# The price is $269
# The price is $269
# The price is $269
# The price is $269
# The price is $270
# The price is $271
# The price was $301
# The price is $271
# The price is $271
# The price is $271
# The price was $319
# The price is $271
# The price is $272
# The price was $392
# The price is $274
# The price is $275
# The price was $323
# The price is $275
# The price is $275
# The price is $275
# The price was $324
# The price is $275
# The price is $276
# The price is $277
# The price is $278
# The price is $278
# The price is $278
# The price is $278
# The price was $309
# The price is $278
# The price is $279
# The price is $279
# The price is $279
# The price is $279
# The price is $280
# The price was $329
# The price is $280
# The price is $283
# The price is $283
# The price is $284
# The price is $284
# The price is $284
# The price is $284
# The price is $284
# The price is $284
# The price is $284
# The price is $284
# The price is $287
# The price was $359
# The price is $287
# The price is $288
# The price is $288
# The price is $288
# The price is $289
# The price is $289
# The price is $289
# The price is $289
# The price is $289
# The price is $289
# The price is $290
# The price is $290
# The price is $291
# The price was $343
# The price is $292
# The price is $292
# The price was $328
# The price is $293
# The price is $294
# The price is $295
# The price is $296
# The price is $296
# The price is $296
# The price is $296
# The price is $296
# The price is $297
# The price is $298
# The price is $299
# The price is $299
# The price is $299
# The price is $299
# The price is $299
# The price is $299
# The price is $299
# The price is $299
# The price is $301
# The price is $302
# The price is $303
# The price is $303
# The price is $304
# The price is $305
# The price is $305
# The price is $305
# The price is $305
# The price is $305
# The price is $307
# The price is $307
# The price is $307
# The price was $343
# The price is $309
# The price is $309
# The price is $309
# The price is $311
# The price was $366
# The price is $311
# The price was $366
# The price is $311
# The price was $346
# The price is $311
# The price is $314
# The price is $314
# The price is $318
# The price is $318
# The price was $375
# The price is $319
# The price was $375
# The price is $319
# The price is $319
# The price is $319
# The price is $319
# The price is $319
# The price is $319
# The price is $319
# The price is $319
# The price is $319
# The price is $319
# The price was $399
# The price is $319
# The price is $320
# The price is $320
# The price is $322
# The price is $322
# The price is $322
# The price was $358
# The price is $322
# The price was $359
# The price is $323
# The price is $323
# The price is $325
# The price was $362
# The price is $325
# The price is $325
# The price is $329
# The price is $329
# The price is $329
# The price is $329
# The price is $329
# The price is $329
# The price was $366
# The price is $329
# The price is $331
# The price is $331
# The price is $331
# The price is $332
# The price is $332
# The price is $332
# The price is $334
# The price is $335
# The price is $335
# The price is $335
# The price is $336
# The price was $374
# The price is $337
# The price was $375
# The price is $338
# The price is $339
# The price is $339
# The price is $339
# The price is $339
# The price is $339
# The price is $339
# The price is $341
# The price is $342
# The price is $342
# The price is $344
# The price was $405
# The price is $344
# The price is $345
# The price is $345
# The price was $385
# The price is $347
# The price was $394
# The price is $347
# The price was $408
# The price is $347
# The price was $409
# The price is $348
# The price is $349
# The price is $349
# The price is $349
# The price is $349
# The price is $349
# The price is $349
# The price is $349
# The price is $349
# The price is $350
# The price is $350
# The price was $400
# The price is $352
# The price was $374
# The price is $355
# The price was $395
# The price is $356
# The price was $419
# The price is $356
# The price was $732
# The price is $359
# The price is $359
# The price is $359
# The price is $359
# The price is $359
# The price is $359
# The price is $359
# The price is $359
# The price was $552
# The price is $359
# The price is $359
# The price was $399
# The price is $359
# The price is $360
# The price is $361
# The price is $362
# The price is $363
# The price is $364
# The price was $608
# The price is $365
# The price is $365
# The price is $366
# The price is $367
# The price is $368
# The price is $369
# The price is $373
# The price is $376
# The price is $377
# The price is $377
# The price is $381
# The price is $382
# The price is $384
# The price is $384
# The price is $385
# The price is $386
# The price is $389
# The price is $389
# The price is $390
# The price is $391
# The price is $392
# The price is $396
# The price is $398
# The price is $399
# The price is $399
# The price is $399
# The price is $399
# The price is $399
# The price is $401
# The price is $404
# The price is $404
# The price is $404
# The price was $449
# The price is $404
# The price is $405
# The price is $407
# The price was $585
# The price is $409
# The price is $412
# The price is $412
# The price is $415
# The price is $416
# The price is $419
# The price is $419
# The price is $422
# The price is $424
# The price is $425
# The price is $429
# The price is $431
# The price is $433
# The price is $439
# The price is $446
# The price is $448
# The price is $449
# The price is $449
# The price is $449
# The price is $454
# The price is $458
# The price is $465
# The price is $465
# The price was $518
# The price is $466
# The price is $469
# The price is $474
# The price is $474
# The price is $474
# The price is $474
# The price was $679
# The price is $475
# The price was $972
# The price is $476
# The price was $564
# The price is $479
# The price was $650
# The price is $488
# The price is $489
# The price is $493
# The price is $494
# The price is $495
# The price is $501
# The price is $512
# The price is $525
# The price is $529
# The price is $534
# The price is $535
# The price is $536
# The price is $547
# The price is $548
# The price is $549
# The price is $565
# The price was $813
# The price is $569
# The price is $571
# The price is $574
# The price is $579
# The price is $585
# The price is $589
# The price is $591
# The price is $596
# The price is $599
# The price is $605
# The price is $608
# The price is $609
# The price is $633
# The price was $745
# The price is $633
# The price was $764
# The price is $649
# The price is $669
# The price is $695
# The price is $699
# The price is $699
# The price is $699
# The price is $718
# The price is $741
# The price is $741
# The price is $750
# The price was $850
# The price is $765
# The price is $785
# The price is $795
# The price is $795
# The price is $806
# The price was $895
# The price is $806
# The price is $825
# The price is $825
# The price is $835
# The price was $895
# The price is $850
# The price is $854
# The price is $870
# The price is $878
# The price is $895
# The price is $896
# The price is $985
# The price is $1,050
# The price is $1,505
# The price is $9,999

# %%
import pandas as pd

# %%
price_test_df = pd.DataFrame(price)
price_test_df.head()
# Out:
#                    0
# 0   The price is $79
# 1   The price is $81
# 2  The price was $93
# 3   The price is $83
# 4   The price is $85

# %%
price_test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       912 non-null    object
# dtypes: object(1)
# memory usage: 7.2+ KB

# %%
total =

# %%
browser.quit()

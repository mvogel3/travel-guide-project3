# %%
# !pip install amadeus
from amadeus import ResponseError, Client
from pprint import pprint
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for amadeus: filename=amadeus-8.0.0-py2.py3-none-any.whl size=73238 sha256=28ab1b8cba6e93f54f57aa8c8f596b6ca2ac152acf4890d6de5c212914de0061
#   Stored in directory: /Users/megvogel/Library/Caches/pip/wheels/44/47/35/ebd487d4dd6c82071fe2ff4fd1b94515cde3750d6eae34c8fa
# Successfully built amadeus
# ...

# %%
amadeus = Client(
    client_id='7EROxQ2PLbAkYqcG9uElxtXETjKXdpoN',
    client_secret='Z9F0VMyelxwhSDlH'
)

try:
    '''
    Get list of hotels in cities: New York City, Long Island City, Mount Vernon, White Plains, Yonkers, New Rochelle
    '''
    # Set the geographical coordinates
    cities_lat = [{'latitude': 40.7128, 'longitude': -74.0060, 'name': 'New York City'},
                  {'latitude': 13.023577, 'longitude': 77.642256, 'name': 'Bangalore'},
                  {'latitude': 41.42, 'longitude': 2.228208, 'name': 'Barcelona'},
                  {'latitude': 52.541755, 'longitude': 13.457198, 'name': 'Berlin'},
                  {'latitude': 32.806993, 'longitude': -96.737293, 'name': 'Dallas'},
                  {'latitude': 51.520180, 'longitude': -0.061048, 'name': 'London'},
                  {'latitude': 48.91, 'longitude': 2.46, 'name': 'Paris'},
                  {'latitude': 37.810980, 'longitude': -122.370076, 'name': 'San Francisco'}]
    # Retrieve hotel data for New York City
    response_nyc = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-74.0060, latitude=40.7128)
    hotel_data_nyc = response_nyc.data
    pprint(hotel_data_nyc)
    
    # Retrieve hotel data for Long Island City
    response_lic = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-73.9360, latitude=40.7340)
    hotel_data_lic = response_lic.data
    pprint(hotel_data_lic)
    
    # Retrieve hotel data for Mount Vernon
    response_mv = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-73.8290816, latitude=40.9136005)
    hotel_data_mv = response_mv.data
    pprint(hotel_data_mv)
    
    # Retrieve hotel data for White Plains
    response_wp = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-73.762909, latitude=41.033985)
    hotel_data_wp = response_wp.data
    pprint(hotel_data_wp)
     # Retrieve hotel data for Yonkers
    response_yo = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-73.9247, latitude=40.9025)
    hotel_data_yo = response_yo.data
    pprint(hotel_data_yo)
    
    # Retrieve hotel data for New Rochelle
    response_nr = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-73.7793, latitude=40.9232)
    hotel_data_nr = response_nr.data
    pprint(hotel_data_nr)
    
    # Retrieve hotel data for Jersey City
    response_jc = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-74.0737, latitude=40.7127)
    hotel_data_jc = response_jc.data
    pprint(hotel_data_jc)
    
    # Retrieve hotel data for Newark
    response_newark = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-74.2095504, latitude=40.7094091)
    hotel_data_newark = response_newark.data
    pprint(hotel_data_newark)
    
    # Retrieve hotel data for New Haven
    response_nh = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-72.9272, latitude=41.3069)
    hotel_data_nh = response_nh.data
    pprint(hotel_data_nh)
    
    # Retrieve hotel data for Bridgeport
    response_bri = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-73.1972645346039, latitude=41.1936893070528)
    hotel_data_bri = response_bri.data
    pprint(hotel_data_bri)
    
    # Retrieve hotel data for Greenwich
    response_gr = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-73.6243386, latitude=41.0376034)
    hotel_data_gr = response_gr.data
    pprint(hotel_data_gr)
    
    # Retrieve hotel data for Hempstead
    response_he = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-73.5359, latitude=40.7288)
    hotel_data_he = response_he.data
    pprint(hotel_data_he)
    
    # Retrieve hotel data for Norwalk
    response_no = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-73.4015257, latitude=41.1382333)
    hotel_data_no = response_no.data
    pprint(hotel_data_no)
    
    # Retrieve hotel data for Secaucus
    response_se = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-74.0676485, latitude=40.781958)
    hotel_data_se = response_se.data
    pprint(hotel_data_se)
    
    # Retrieve hotel data for Stamford
    response_st = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-73.542914, latitude=41.0883695)
    hotel_data_st = response_st.data
    pprint(hotel_data_st)
    
    # Retrieve hotel data for Tarrytown
    response_ta = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-73.8094, latitude=41.1257)
    hotel_data_ta = response_ta.data
    pprint(hotel_data_ta)
    
    # Retrieve hotel data for Queens
    response_qu = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-73.5359, latitude=40.7288)
    hotel_data_qu = response_qu.data
    pprint(hotel_data_qu)
    
    # Retrieve hotel data for Brooklyn
    response_bro = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-73.9545, latitude=40.6413)
    hotel_data_bro = response_bro.data
    pprint(hotel_data_bro)
    
    # Retrieve hotel data for Jamaica
    response_ja = amadeus.reference_data.locations.hotels.by_geocode.get(longitude=-73.9545, latitude=40.6413)
    hotel_data_bro = response_bro.data
    pprint(hotel_data_bro)
    
    
    
except ResponseError as error:
    raise error
# Out:
# [{'address': {'countryCode': 'US'},
#   'chainCode': 'OK',
#   'distance': {'unit': 'KM', 'value': 0.21},
#   'dupeId': 700109433,
#   'geoCode': {'latitude': 40.71455, 'longitude': -74.00714},
#   'hotelId': 'OKNYC062',
#   'iataCode': 'NYC',
#   'lastUpdate': '2022-11-29T09:06:07',
#   'name': 'TEST PROPERTY'},
#  {'address': {'countryCode': 'US'},
#   'chainCode': 'XT',
#   'distance': {'unit': 'KM', 'value': 0.22},
#   'dupeId': 700100647,
#   'geoCode': {'latitude': 40.71143, 'longitude': -74.00789},
#   'hotelId': 'XTNYCCPR',
#   'iataCode': 'NYC',
#   'lastUpdate': '2022-11-29T09:08:10',
#   'name': 'CHURCHILL AT 15 PARK ROW'},
#  {'address': {'countryCode': 'US'},
#   'chainCode': 'XT',
#   'distance': {'unit': 'KM', 'value': 0.36},
#   'dupeId': 700070576,
#   'geoCode': {'latitude': 40.71586, 'longitude': -74.00745},
#   'hotelId': 'XTNYC130',
#   'iataCode': 'NYC',
#   'lastUpdate': '2022-11-29T09:08:02',
#   'name': 'DUANE STREET HOTEL'},
# ...
